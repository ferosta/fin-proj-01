# %%
from rss_parser import Parser
from requests import get
import pandas as pd
import os 
import json
import time
from datetime import datetime, timezone

import sqlalchemy
from sqlalchemy import create_engine, MetaData,Table, Column, Numeric, Integer, VARCHAR, text
from sqlalchemy.engine import result

# %% [markdown]
# # Конфигурационные настройки

# %% [markdown]
# ## Логирование

# %%
# логирование
# PRJ_DIR = "" #'/home/fedorov/mypy/vk_prj/'
# if PRJ_DIR not in sys.path:
#     sys.path.insert(0, PRJ_DIR)
##########################################
# логирование
# лучше бы использовать loguru
import logging
import logging.config
dictLogConfig = {
    "version":1,
    "handlers":{
        "StreamHandler":{
            "class":"logging.StreamHandler",
            "formatter":"myFormatter"
        },
        "GlobalfileHandler":{
            "class":"logging.handlers.RotatingFileHandler",
            "formatter":"myFormatter",
            "filename": "LOG_.LOG",
            "backupCount": 10
        },
        "fileHandlerDEBUG":{
            "class":"logging.FileHandler",
            "formatter":"myFormatter",
            "filename": "DEBUG.LOG"
        },
         "fileHandlerINFO":{
            "class":"logging.FileHandler",
            "formatter":"myFormatter",
            "filename": "LOG_.LOG"
        },
    },
    "loggers":{
        "DEBUG":{
            "handlers":["fileHandlerDEBUG", "StreamHandler"],
            "level":"DEBUG",
        },
        "INFO":{
            "handlers":["fileHandlerINFO", "GlobalfileHandler"],
            "level":"INFO",
        },
        "WARNING":{
            "handlers":["fileHandlerINFO", "GlobalfileHandler"],
            "level":"WARNING",
        },
        "ERROR":{
            "handlers":["fileHandlerINFO", "GlobalfileHandler"],
            "level":"ERROR",
        },
        "CRITICAL":{
            "handlers":["fileHandlerINFO", "GlobalfileHandler"],
            "level":"CRITICAL",
        }
    },
    "formatters":{
        "myFormatter":{
            "format":"%(asctime)s:%(name)s:%(levelname)s=>%(message)s<=%(filename)s->%(funcName)s[%(lineno)d]"
        }
    }
}
logging.config.dictConfig(dictLogConfig)


PROG_NAME = 'GET_RSS_DATA'
# logger = logging.getLogger("INFO."+PROG_NAME)
# logger = logging.getLogger("INFO."+PROG_NAME)
logger = logging.getLogger("DEBUG."+PROG_NAME)

# %% [markdown]
# ## Глобальные переменные

# %%
# конфигурационные настройки
CONFIG_FILE_NAME = os.path.abspath(u'./config/rss_links.csv')
DATA_DIR_NAME = os.path.abspath(u'./data')

PGS_LGIN = 'postgres'
PGS_PSWD = 'postgres'
PGS_DB = 'postgres'
PGS_ADDR = ' 192.168.144.9' #172.17.0.1
PGS_PORT = 5440

SQL_ENGINE = create_engine(f'postgresql://{PGS_LGIN}:{PGS_PSWD}@localhost:{PGS_PORT}/{PGS_DB}')

# %% [markdown]
# # Чтение конфига с адресами источников РСС

# %%
# читаем конфиг со ссылками на источники
def read_config(CONFIG_FILE_NAME):
    """читаем конфиг со ссылками на источники
        CONFIG_FILE_NAME - имя файла с конфигом (если не в локальной директории то с путём)
    """
    df_config = pd.read_csv(CONFIG_FILE_NAME, header=None  )
    rss_urls = list(df_config[0])
    logger.debug(f'Ссылки на источники прочитаны из {CONFIG_FILE_NAME}')
    return rss_urls


# rss_urls = read_config(CONFIG_FILE_NAME)
# rss_urls

# %% [markdown]
# # Подготовка первичного хранилища для данных из источников

# %%
def rssname_to_dirname(rss_url:str):
    """ из адреса ссылки на источник делает имя папки для хранения фидов из этого источника
        Результат: название папки с фидами источника
    """
    # rss_url = 'https://regnum.ru/rss'# 'https://ria.ru/export/rss2/archive/index.xml' #'https://lenta.ru/rss/' # rss_urls[0]
    rss_dirname = rss_url.replace(u'https://', "").replace(u"/","|") 
    # abs_rss_dirname = os.path.join(DATA_DIR_NAME, rss_dirname)
    return rss_dirname

    
# подготовить: проверить и если надо создать каталог под данные из источника
def rss_dir_prepare(rss_url):
    """ Проверить есть ли каталог для данного источника,
        Если нет, то создать каталог для сохранения сведений из источника .
        rss_url - ссылка на источник из конфиг-файла
    """
    # получаем имя папки с данными из ссылки на источник
    rss_dir_name = rssname_to_dirname(rss_url)# rss_url.replace(u'https://', "").replace(u"/","|")
    logger.debug(f'Проверяется папка rss_dir_name = {rss_dir_name}')
    
    # полный путь до папки с данными
    rss_full_dir_name = os.path.join(DATA_DIR_NAME , rss_dir_name ) 
    rss_abs_dir_name =  rss_full_dir_name #os.path.abspath(rss_full_dir_name)
    
    # если такой папки еще нет - то создаем
    if not os.path.exists(rss_abs_dir_name):
        os.mkdir(rss_abs_dir_name)
        logger.debug(f'Создна папка {rss_abs_dir_name}')
    
    return rss_abs_dir_name

    
# rss_url = 'https://lenta.ru/rss/' # rss_urls[0]
# rss_dirname = rss_dir_prepare(rss_url)

# %% [markdown]
# # Получение данных из источника по ссылке

# %%
# получение данных из источника по ссылке rss_url 
def get_rss(url : str):
    """ получение данных из источника по ссылке rss_url 
        Результат: словарь feed
    """
    # получаем данны из источника - всю порцию,которую он отдает. Настроек по выбору времени там нет!
    xml = get(url)
    parser = Parser(xml=xml.content  ) 
    feed = parser.parse()
    logger.debug(f'Данные из {url} получены. Кол-во записей: { len( feed.dict()["feed"]) }. Код Ок: {xml.ok}')
    return feed.dict()['feed']

# rss_url = 'https://lenta.ru/rss/' # rss_urls[0]
# rss_feed = get_rss(rss_url)

# %% [markdown]
# # Сохранение полученных из истончика данных в файл

# %%
# преобразование даты из строки в datetime с timezone
def convert_to_tz_datetime(dt : str): 
    """ преобразование даты из строки в datetime с timezone
    """
    # формат даты #'Sat, 24 Dec 2022 09:10:22 +0300'   
    fmt = "%a, %d %b %Y %H:%M:%S %z" 
    # код таймзоны
    tz = datetime.strptime('+0300', '%z').tzinfo
    
    rez = datetime.now().astimezone(tz).strptime(dt, fmt)
    logger.debug(rez.strftime(fmt) )
    return rez


# сохранение полученного и распаршенного rss в файл
def save_rss_feed(feed_dict : dict, dir_to_save :str):
    """ сохранение полученного и распаршенного rss в файл
        вх: rss_feed - словарь с новостями
            dir_to_save - путь до директории сохранения
    """
    # формирование имени файла, в который записывается порция данных rss
    # текущий таймстамп - для уникального имени файла
    now_timestamp = int(datetime.now().timestamp())
    
    # #даты первой и последней новости в порции рсс
    # pub_date_to = convert_to_tz_datetime( rss_feed[0]['publish_date'] )
    # pub_date_from = convert_to_tz_datetime( rss_feed[-1]['publish_date'] )

    # #имя файла для сохранения порции рсс
    # fmt = "%Y-%m-%d_%H-%M-%S"
    # file_name_dic = {'to':pub_date_to.strftime(fmt), 'from': pub_date_from.strftime(fmt) }
    # file_name_str = json.dumps(file_name_dic).replace(": ",'|')
    # file_name_str
    
    # сохранение полученной порции rss в директорию источника

    # полное имя файла для записи
    abs_filename = os.path.join(dir_to_save, str(now_timestamp) + '.json')
    with open(abs_filename, mode="w") as fp:
        json.dump(feed_dict , fp )
        logger.debug(f'Rss_feed записан в файл {abs_filename}')
    
    return abs_filename

        
# rss_filename = save_rss_feed(rss_feed, rss_dirname)

# %% [markdown]
# # Тест 1: Загрузка данных из одного источник rss

# %%
def get_one_rss_data():
    # читаем конфиг с адресами источников РСС
    rss_urls = read_config(CONFIG_FILE_NAME)

    # подготавливаем папки для хранения скачиваемых из РСС данных
    rss_url = 'https://lenta.ru/rss/' # rss_urls[0]
    rss_dirname = rss_dir_prepare(rss_url)

    # получаем порцию данных по ссылке
    # rss_url = 'https://lenta.ru/rss/' # rss_urls[0]
    rss_feed = get_rss(rss_url)

    # сохраняем данные в заранее подготовленной папке
    rss_filename = save_rss_feed(rss_feed, rss_dirname)

# %% [markdown]
# # Загрузка данных из всех источников RSS

# %%
def get_all_rss_data():
    """ Получение данных из всех источников """
    # читаем конфиг с адресами источников РСС
    rss_urls = read_config(CONFIG_FILE_NAME)

    for url in rss_urls:

        # подготавливаем папки для хранения скачиваемых из РСС данных
        dirname = rss_dir_prepare(url)

        # получаем порцию данных по ссылке
        feed = get_rss(url)

        # сохраняем данные в заранее подготовленной папке
        rez_filename = save_rss_feed(feed, dirname)


if "DEBUG" in logger.name:
    get_all_rss_data()
# Out:
# 2022-12-27 19:42:53,174:DEBUG.GET_RSS_DATA:DEBUG=>Ссылки на источники прочитаны из /home/fedorov/mypy/dataeng/fin-prj-01/config/rss_links.csv<=3992747886.py->read_config[8]
# 2022-12-27 19:42:53,182:DEBUG.GET_RSS_DATA:DEBUG=>Проверяется папка rss_dir_name = lenta.ru|rss|<=1236541857.py->rss_dir_prepare[19]
# 2022-12-27 19:42:54,333:DEBUG.GET_RSS_DATA:DEBUG=>Данные из https://lenta.ru/rss/ получены. Кол-во записей: 200. Код Ок: True<=1369716965.py->get_rss[10]
# 2022-12-27 19:42:54,353:DEBUG.GET_RSS_DATA:DEBUG=>Rss_feed записан в файл /home/fedorov/mypy/dataeng/fin-prj-01/data/lenta.ru|rss|/1672159374.json<=767735444.py->save_rss_feed[41]
# 2022-12-27 19:42:54,354:DEBUG.GET_RSS_DATA:DEBUG=>Проверяется папка rss_dir_name = www.vedomosti.ru|rss|news<=1236541857.py->rss_dir_prepare[19]
# 2022-12-27 19:42:55,124:DEBUG.GET_RSS_DATA:DEBUG=>Данные из https://www.vedomosti.ru/rss/news получены. Кол-во записей: 200. Код Ок: True<=1369716965.py->get_rss[10]
# 2022-12-27 19:42:55,136:DEBUG.GET_RSS_DATA:DEBUG=>Rss_feed записан в файл /home/fedorov/mypy/dataeng/fin-prj-01/data/www.vedomosti.ru|rss|news/1672159375.json<=767735444.py->save_rss_feed[41]
# 2022-12-27 19:42:55,136:DEBUG.GET_RSS_DATA:DEBUG=>Проверяется папка rss_dir_name = tass.ru|rss|v2.xml<=1236541857.py->rss_dir_prepare[19]
# 2022-12-27 19:42:55,638:DEBUG.GET_RSS_DATA:DEBUG=>Данные из https://tass.ru/rss/v2.xml получены. Кол-во записей: 98. Код Ок: True<=1369716965.py->get_rss[10]
# 2022-12-27 19:42:55,648:DEBUG.GET_RSS_DATA:DEBUG=>Rss_feed записан в файл /home/fedorov/mypy/dataeng/fin-prj-01/data/tass.ru|rss|v2.xml/1672159375.json<=767735444.py->save_rss_feed[41]
# 2022-12-27 19:42:55,649:DEBUG.GET_RSS_DATA:DEBUG=>Проверяется папка rss_dir_name = ria.ru|export|rss2|archive|index.xml<=1236541857.py->rss_dir_prepare[19]
# 2022-12-27 19:42:56,021:DEBUG.GET_RSS_DATA:DEBUG=>Данные из https://ria.ru/export/rss2/archive/index.xml получены. Кол-во записей: 100. Код Ок: True<=1369716965.py->get_rss[10]
# 2022-12-27 19:42:56,031:DEBUG.GET_RSS_DATA:DEBUG=>Rss_feed записан в файл /home/fedorov/mypy/dataeng/fin-prj-01/data/ria.ru|export|rss2|archive|index.xml/1672159376.json<=767735444.py->save_rss_feed[41]
# 2022-12-27 19:42:56,032:DEBUG.GET_RSS_DATA:DEBUG=>Проверяется папка rss_dir_name = www.kommersant.ru|RSS|news.xml<=1236541857.py->rss_dir_prepare[19]
# /home/fedorov/anaconda3/envs/newconda/lib/python3.10/site-packages/bs4/__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# 2022-12-27 19:42:56,701:DEBUG.GET_RSS_DATA:DEBUG=>Данные из https://www.kommersant.ru/RSS/news.xml получены. Кол-во записей: 329. Код Ок: True<=1369716965.py->get_rss[10]
# 2022-12-27 19:42:56,717:DEBUG.GET_RSS_DATA:DEBUG=>Rss_feed записан в файл /home/fedorov/mypy/dataeng/fin-prj-01/data/www.kommersant.ru|RSS|news.xml/1672159376.json<=767735444.py->save_rss_feed[41]
# 2022-12-27 19:42:56,718:DEBUG.GET_RSS_DATA:DEBUG=>Проверяется папка rss_dir_name = rossaprimavera.ru|rss<=1236541857.py->rss_dir_prepare[19]
# 2022-12-27 19:42:57,110:DEBUG.GET_RSS_DATA:DEBUG=>Данные из https://rossaprimavera.ru/rss получены. Кол-во записей: 51. Код Ок: True<=1369716965.py->get_rss[10]
# 2022-12-27 19:42:57,119:DEBUG.GET_RSS_DATA:DEBUG=>Rss_feed записан в файл /home/fedorov/mypy/dataeng/fin-prj-01/data/rossaprimavera.ru|rss/1672159377.json<=767735444.py->save_rss_feed[41]
# 2022-12-27 19:42:57,120:DEBUG.GET_RSS_DATA:DEBUG=>Проверяется папка rss_dir_name = regnum.ru|rss<=1236541857.py->rss_dir_prepare[19]
# 2022-12-27 19:42:57,690:DEBUG.GET_RSS_DATA:DEBUG=>Данные из https://regnum.ru/rss получены. Кол-во записей: 100. Код Ок: True<=1369716965.py->get_rss[10]
# 2022-12-27 19:42:57,703:DEBUG.GET_RSS_DATA:DEBUG=>Rss_feed записан в файл /home/fedorov/mypy/dataeng/fin-prj-01/data/regnum.ru|rss/1672159377.json<=767735444.py->save_rss_feed[41]
# 2022-12-27 19:42:57,703:DEBUG.GET_RSS_DATA:DEBUG=>Проверяется папка rss_dir_name = www.cnews.ru|inc|rss|news.xml<=1236541857.py->rss_dir_prepare[19]
# 2022-12-27 19:42:58,192:DEBUG.GET_RSS_DATA:DEBUG=>Данные из https://www.cnews.ru/inc/rss/news.xml получены. Кол-во записей: 200. Код Ок: True<=1369716965.py->get_rss[10]
# 2022-12-27 19:42:58,212:DEBUG.GET_RSS_DATA:DEBUG=>Rss_feed записан в файл /home/fedorov/mypy/dataeng/fin-prj-01/data/www.cnews.ru|inc|rss|news.xml/1672159378.json<=767735444.py->save_rss_feed[41]
# 2022-12-27 19:42:58,213:DEBUG.GET_RSS_DATA:DEBUG=>Проверяется папка rss_dir_name = hibinform.ru|feed|<=1236541857.py->rss_dir_prepare[19]
# 2022-12-27 19:42:58,719:DEBUG.GET_RSS_DATA:DEBUG=>Данные из https://hibinform.ru/feed/ получены. Кол-во записей: 10. Код Ок: True<=1369716965.py->get_rss[10]
# 2022-12-27 19:42:58,722:DEBUG.GET_RSS_DATA:DEBUG=>Rss_feed записан в файл /home/fedorov/mypy/dataeng/fin-prj-01/data/hibinform.ru|feed|/1672159378.json<=767735444.py->save_rss_feed[41]
# 2022-12-27 19:42:58,722:DEBUG.GET_RSS_DATA:DEBUG=>Проверяется папка rss_dir_name = habr.com|ru|rss|all|all|<=1236541857.py->rss_dir_prepare[19]
# 2022-12-27 19:42:59,235:DEBUG.GET_RSS_DATA:DEBUG=>Данные из https://habr.com/ru/rss/all/all/ получены. Кол-во записей: 20. Код Ок: True<=1369716965.py->get_rss[10]
# 2022-12-27 19:42:59,239:DEBUG.GET_RSS_DATA:DEBUG=>Rss_feed записан в файл /home/fedorov/mypy/dataeng/fin-prj-01/data/habr.com|ru|rss|all|all|/1672159379.json<=767735444.py->save_rss_feed[41]

# %% [markdown]
# # Инициализирующая Загрузка данных из файлов в хранилище (БД)

# %% [markdown]
# ## Прочитать файл и сделать из него таблицу пандас

# %%
# прочитать из фид-файла и записать в пандас датафрейм
def feedfile_to_pandas(rss_url:str, rss_file_name:str):
    """ Читает json файл с сохраненным feed и преобразует его в таблицу пандас
        rss_url - название папки с файлами-фидами источника
        rss_file_name - имя файла с фидом
        Результат: таблица пандас
    """
    
    # формируем полное имя файла
    rss_dirname = rssname_to_dirname(rss_url) 
    rss_full_dirname = os.path.join(DATA_DIR_NAME, rss_dirname)
    feed_filename = os.path.join(rss_full_dirname, rss_file_name)
    
    
    # открываем первый файл - это самый новый, т.к. сотритовка обратная
    feed=''
    with open(feed_filename, 'r') as fp:
        feed = json.load(fp)
        logger.debug(f'Прочитали содержимое файла {feed_filename}. Кол-во записей: {len(feed)}')

    # закидываем фид в пандас : колонки только те, которые нужны
    columns = ['title', 'link', 'publish_date', 'category', 'description' ] # 'description_links', 'description_images', 'enclosure', 'itunes'
    df = pd.json_normalize(feed)[columns]
    # добавляем признак источника
    df['source'] = rss_dirname
    
    logger.debug(f'Из файла {feed_filename} получили таблицу, кол-во строк {len(df)}.')
    return df

# тест feedfile_to_pandas
# rss_url = 'https://regnum.ru/rss'
# feed_filename = '1672120674.json'
# df1 = feedfile_to_pandas(rss_url, feed_filename)
# df1

# %% [markdown]
# ## (SQL) Начальная инициализация: Объединить все файлы из папки источника рсс в таблицы в БД

# %%
# df0.to_sql('regnum.ru|rss'+'0', SQL_ENGINE, if_exists='replace')
# df1.to_sql('regnum.ru|rss'+'1', SQL_ENGINE, if_exists='replace')
# SQL_ENGINE.table_names()
# sql =  text("""
# SELECT * from "regnum.ru|rss" LIMIT 5
           
#            """)
# # results = SQL_ENGINE.execute(sql)
# # # View the records
# # for record in results:
# #     print("\n", record)
# Out:
# /tmp/ipykernel_88673/2936477119.py:3: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
#   SQL_ENGINE.table_names()
# ['xxx', 'regnum.ru|rss', 'regnum.ru|rss0', 'regnum.ru|rss1']

# %%
# def join_all_feedfiles_to_SQL(rss_url: str):
#     """" Взять все файлы с фидами в папке рсс и объединить их, убрав повторения, записав в основное хранилище SQL
#         Результат: готовая начальная SQL-таблица
#     """
#     # подготавливаем имя папки для чтения скачанных из РСС данных - отдельных файлов
#     rss_dirname = rssname_to_dirname(rss_url) #rss_url.replace(u'https://', "").replace(u"/","|") # rss_dir_prepare(rss_url)
#     abs_rss_dirname = os.path.join(DATA_DIR_NAME, rss_dirname)
    
#     # получаем список сохраненных файлов
#     list_dir = [ fn for fn in sorted( os.listdir(abs_rss_dirname), reverse=True) if '.json' in fn]
#     logger.debug(f'Прочитали директорию {abs_rss_dirname}. Кол-во файлов: {len(list_dir)}. Список: {list_dir}')
    
    
#     #подготовка таблицы в БД
#     engine = 
    
#     for rf in list_dir:
#         # получаем датафрейм пандас для файла
#         df = feedfile_to_pandas(rss_url, rf)
        
#         #для отладки инфо: превая и последняя запись датафрефма
#         str_fst = df.iloc[0,:][['publish_date', 'title']].to_string().replace('  ',"").replace('publish_date',"").replace('\ntitle',"")[:50]
#         str_lst = df.iloc[-1,:][['publish_date', 'title']].to_string().replace('  ',"").replace('publish_date',"").replace('\ntitle',"")[:50]
#         logger.debug(f'Таблица для файла:{rf}, строк:{len(df)}, нач.:{str_fst}, кон.:{str_lst}')
#         # объединяем полученное с имеющимся 
#         # if df_rez.empty:
#         #     df_rez = df
#         #     logger.debug(f'Начальная инициализация пустой таблицы')
#         df_rez = pd.concat([df_rez, df], ignore_index=True )
        
#         df.to_sql(,SQL_ENGINE)
        
        
    
    
#     logger.debug(f'Сформировали сводную таблицу для файлов в {abs_rss_dirname}. Кол-во строк: {len(df_rez)}')
#     df_rez.drop_duplicates(ignore_index=True, inplace=True)
#     logger.debug(f'После удаления дубликатов: кол-во строк: {len(df_rez)}')
    
#     return df_rez

# %% [markdown]
# ## 1. (Pandas) Начальная инициализация: Объединить все файлы из папки источника рсс и записать результат в хранилище

# %%
def join_all_feedfiles_pandas_sql(rss_url: str):
    """ взять все файлы с фидами в папке рсс, объединить их, убрав повторения и приготовить к записи в хранилище (?БД)
        Результат: таблица пандас с уникальными записями из всех файлов в папке источника
    """
    # подготавливаем имя папки для чтения скачанных из РСС данных - отдельных файлов
    rss_dirname = rssname_to_dirname(rss_url) #rss_url.replace(u'https://', "").replace(u"/","|") # rss_dir_prepare(rss_url)
    abs_rss_dirname = os.path.join(DATA_DIR_NAME, rss_dirname)
    
    # получаем список сохраненных файлов
    list_dir = [ fn for fn in sorted( os.listdir(abs_rss_dirname), reverse=True) if '.json' in fn]
    logger.debug(f'Прочитали директорию {abs_rss_dirname}. Кол-во файлов: {len(list_dir)}. Список: {list_dir}')
    
    df_rez = pd.DataFrame()
    
    for rf in list_dir:
        # получаем датафрейм пандас для файла
        df = feedfile_to_pandas(rss_url, rf)
        
        #для отладки инфо: превая и последняя запись датафрефма
        str_fst = df.iloc[0,:][['publish_date', 'title']].to_string().replace('  ',"").replace('publish_date',"").replace('\ntitle',"")[:50]
        str_lst = df.iloc[-1,:][['publish_date', 'title']].to_string().replace('  ',"").replace('publish_date',"").replace('\ntitle',"")[:50]
        logger.debug(f'Таблица для файла:{rf}, строк:{len(df)}, нач.:{str_fst}, кон.:{str_lst}')
        # объединяем полученное с имеющимся 
        if df_rez.empty:
            df_rez = df
            logger.debug(f'Начальная инициализация пустой таблицы')
        df_rez = pd.concat([df_rez, df], ignore_index=True )
    
    logger.debug(f'Сформировали сводную таблицу для файлов в {abs_rss_dirname}. Кол-во строк: {len(df_rez)}')
    df_rez.drop_duplicates(ignore_index=True, inplace=True)
    logger.debug(f'После удаления дубликатов: кол-во строк: {len(df_rez)}')
    
    # добавляем результат в БД
    df_rez.to_sql(rss_dirname, SQL_ENGINE, if_exists='replace')
    logger.debug(f'Добавлено в БД в таблицу: {rss_dirname}')
    
    return df_rez

# # тест
# rss_url = 'https://regnum.ru/rss'#
# df_rez = join_all_feedfiles_pandas_sql(rss_url)

# %% [markdown]
# ## Загрузка данных из всех файлов всех папок источников RSS в SQL через pandas

# %%
def load_all_feeddirs_to_sql():
    """ Загрузка всех данных из папок источников в SQL , через объединение их в pandas"""
    # читаем конфиг с адресами источников РСС
    rss_urls = read_config(CONFIG_FILE_NAME)

    for url in rss_urls:

        # группируем все в один датафрейм и записываем его в SQL
        join_all_feedfiles_pandas_sql(url)


if "DEBUG" in logger.name:
    # можно сначала загрузить свежую порцию фидов 
    get_all_rss_data()
    # а потом закинуть все в БД
    load_all_feeddirs_to_sql()
# Out:
# 2022-12-27 19:45:31,435:DEBUG.GET_RSS_DATA:DEBUG=>Ссылки на источники прочитаны из /home/fedorov/mypy/dataeng/fin-prj-01/config/rss_links.csv<=3992747886.py->read_config[8]
# 2022-12-27 19:45:31,437:DEBUG.GET_RSS_DATA:DEBUG=>Проверяется папка rss_dir_name = lenta.ru|rss|<=1236541857.py->rss_dir_prepare[19]
# 2022-12-27 19:45:32,015:DEBUG.GET_RSS_DATA:DEBUG=>Данные из https://lenta.ru/rss/ получены. Кол-во записей: 200. Код Ок: True<=1369716965.py->get_rss[10]
# 2022-12-27 19:45:32,028:DEBUG.GET_RSS_DATA:DEBUG=>Rss_feed записан в файл /home/fedorov/mypy/dataeng/fin-prj-01/data/lenta.ru|rss|/1672159532.json<=767735444.py->save_rss_feed[41]
# 2022-12-27 19:45:32,028:DEBUG.GET_RSS_DATA:DEBUG=>Проверяется папка rss_dir_name = www.vedomosti.ru|rss|news<=1236541857.py->rss_dir_prepare[19]
# 2022-12-27 19:45:32,489:DEBUG.GET_RSS_DATA:DEBUG=>Данные из https://www.vedomosti.ru/rss/news получены. Кол-во записей: 200. Код Ок: True<=1369716965.py->get_rss[10]
# 2022-12-27 19:45:32,508:DEBUG.GET_RSS_DATA:DEBUG=>Rss_feed записан в файл /home/fedorov/mypy/dataeng/fin-prj-01/data/www.vedomosti.ru|rss|news/1672159532.json<=767735444.py->save_rss_feed[41]
# 2022-12-27 19:45:32,509:DEBUG.GET_RSS_DATA:DEBUG=>Проверяется папка rss_dir_name = tass.ru|rss|v2.xml<=1236541857.py->rss_dir_prepare[19]
# 2022-12-27 19:45:33,048:DEBUG.GET_RSS_DATA:DEBUG=>Данные из https://tass.ru/rss/v2.xml получены. Кол-во записей: 98. Код Ок: True<=1369716965.py->get_rss[10]
# 2022-12-27 19:45:33,058:DEBUG.GET_RSS_DATA:DEBUG=>Rss_feed записан в файл /home/fedorov/mypy/dataeng/fin-prj-01/data/tass.ru|rss|v2.xml/1672159533.json<=767735444.py->save_rss_feed[41]
# 2022-12-27 19:45:33,059:DEBUG.GET_RSS_DATA:DEBUG=>Проверяется папка rss_dir_name = ria.ru|export|rss2|archive|index.xml<=1236541857.py->rss_dir_prepare[19]
# 2022-12-27 19:45:33,430:DEBUG.GET_RSS_DATA:DEBUG=>Данные из https://ria.ru/export/rss2/archive/index.xml получены. Кол-во записей: 100. Код Ок: True<=1369716965.py->get_rss[10]
# 2022-12-27 19:45:33,438:DEBUG.GET_RSS_DATA:DEBUG=>Rss_feed записан в файл /home/fedorov/mypy/dataeng/fin-prj-01/data/ria.ru|export|rss2|archive|index.xml/1672159533.json<=767735444.py->save_rss_feed[41]
# 2022-12-27 19:45:33,439:DEBUG.GET_RSS_DATA:DEBUG=>Проверяется папка rss_dir_name = www.kommersant.ru|RSS|news.xml<=1236541857.py->rss_dir_prepare[19]
# /home/fedorov/anaconda3/envs/newconda/lib/python3.10/site-packages/bs4/__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# 2022-12-27 19:45:34,107:DEBUG.GET_RSS_DATA:DEBUG=>Данные из https://www.kommersant.ru/RSS/news.xml получены. Кол-во записей: 329. Код Ок: True<=1369716965.py->get_rss[10]
# 2022-12-27 19:45:34,136:DEBUG.GET_RSS_DATA:DEBUG=>Rss_feed записан в файл /home/fedorov/mypy/dataeng/fin-prj-01/data/www.kommersant.ru|RSS|news.xml/1672159534.json<=767735444.py->save_rss_feed[41]
# 2022-12-27 19:45:34,137:DEBUG.GET_RSS_DATA:DEBUG=>Проверяется папка rss_dir_name = rossaprimavera.ru|rss<=1236541857.py->rss_dir_prepare[19]
# 2022-12-27 19:45:34,506:DEBUG.GET_RSS_DATA:DEBUG=>Данные из https://rossaprimavera.ru/rss получены. Кол-во записей: 51. Код Ок: True<=1369716965.py->get_rss[10]
# 2022-12-27 19:45:34,516:DEBUG.GET_RSS_DATA:DEBUG=>Rss_feed записан в файл /home/fedorov/mypy/dataeng/fin-prj-01/data/rossaprimavera.ru|rss/1672159534.json<=767735444.py->save_rss_feed[41]
# 2022-12-27 19:45:34,518:DEBUG.GET_RSS_DATA:DEBUG=>Проверяется папка rss_dir_name = regnum.ru|rss<=1236541857.py->rss_dir_prepare[19]
# 2022-12-27 19:45:35,102:DEBUG.GET_RSS_DATA:DEBUG=>Данные из https://regnum.ru/rss получены. Кол-во записей: 100. Код Ок: True<=1369716965.py->get_rss[10]
# 2022-12-27 19:45:35,134:DEBUG.GET_RSS_DATA:DEBUG=>Rss_feed записан в файл /home/fedorov/mypy/dataeng/fin-prj-01/data/regnum.ru|rss/1672159535.json<=767735444.py->save_rss_feed[41]
# 2022-12-27 19:45:35,135:DEBUG.GET_RSS_DATA:DEBUG=>Проверяется папка rss_dir_name = www.cnews.ru|inc|rss|news.xml<=1236541857.py->rss_dir_prepare[19]
# 2022-12-27 19:45:35,632:DEBUG.GET_RSS_DATA:DEBUG=>Данные из https://www.cnews.ru/inc/rss/news.xml получены. Кол-во записей: 200. Код Ок: True<=1369716965.py->get_rss[10]
# 2022-12-27 19:45:35,644:DEBUG.GET_RSS_DATA:DEBUG=>Rss_feed записан в файл /home/fedorov/mypy/dataeng/fin-prj-01/data/www.cnews.ru|inc|rss|news.xml/1672159535.json<=767735444.py->save_rss_feed[41]
# 2022-12-27 19:45:35,645:DEBUG.GET_RSS_DATA:DEBUG=>Проверяется папка rss_dir_name = hibinform.ru|feed|<=1236541857.py->rss_dir_prepare[19]
# 2022-12-27 19:45:36,316:DEBUG.GET_RSS_DATA:DEBUG=>Данные из https://hibinform.ru/feed/ получены. Кол-во записей: 10. Код Ок: True<=1369716965.py->get_rss[10]
# 2022-12-27 19:45:36,319:DEBUG.GET_RSS_DATA:DEBUG=>Rss_feed записан в файл /home/fedorov/mypy/dataeng/fin-prj-01/data/hibinform.ru|feed|/1672159536.json<=767735444.py->save_rss_feed[41]
# 2022-12-27 19:45:36,320:DEBUG.GET_RSS_DATA:DEBUG=>Проверяется папка rss_dir_name = habr.com|ru|rss|all|all|<=1236541857.py->rss_dir_prepare[19]
# 2022-12-27 19:45:36,742:DEBUG.GET_RSS_DATA:DEBUG=>Данные из https://habr.com/ru/rss/all/all/ получены. Кол-во записей: 20. Код Ок: True<=1369716965.py->get_rss[10]
# 2022-12-27 19:45:36,746:DEBUG.GET_RSS_DATA:DEBUG=>Rss_feed записан в файл /home/fedorov/mypy/dataeng/fin-prj-01/data/habr.com|ru|rss|all|all|/1672159536.json<=767735444.py->save_rss_feed[41]
# 2022-12-27 19:45:36,750:DEBUG.GET_RSS_DATA:DEBUG=>Ссылки на источники прочитаны из /home/fedorov/mypy/dataeng/fin-prj-01/config/rss_links.csv<=3992747886.py->read_config[8]
# 2022-12-27 19:45:36,752:DEBUG.GET_RSS_DATA:DEBUG=>Прочитали директорию /home/fedorov/mypy/dataeng/fin-prj-01/data/lenta.ru|rss|. Кол-во файлов: 9. Список: ['1672159532.json', '1672159374.json', '1672148150.json', '1672126337.json', '1672120671.json', '1672082924.json', '1672080989.json', '1672080885.json', '1672080849.json']<=1933949487.py->join_all_feedfiles_pandas_sql[11]
# 2022-12-27 19:45:36,758:DEBUG.GET_RSS_DATA:DEBUG=>Прочитали содержимое файла /home/fedorov/mypy/dataeng/fin-prj-01/data/lenta.ru|rss|/1672159532.json. Кол-во записей: 200<=1367093449.py->feedfile_to_pandas[19]
# 2022-12-27 19:45:36,764:DEBUG.GET_RSS_DATA:DEBUG=>Из файла /home/fedorov/mypy/dataeng/fin-prj-01/data/lenta.ru|rss|/1672159532.json получили таблицу, кол-во строк 200.<=1367093449.py->feedfile_to_pandas[27]
# 2022-12-27 19:45:36,768:DEBUG.GET_RSS_DATA:DEBUG=>Таблица для файла:1672159532.json, строк:200, нач.:Tue, 27 Dec 2022 19:41:00 +0300 В Италии отчиталис, кон.:Tue, 27 Dec 2022 13:05:00 +0300 Собчак предупредил<=1933949487.py->join_all_feedfiles_pandas_sql[22]
# 2022-12-27 19:45:36,770:DEBUG.GET_RSS_DATA:DEBUG=>Начальная инициализация пустой таблицы<=1933949487.py->join_all_feedfiles_pandas_sql[26]
# 2022-12-27 19:45:36,776:DEBUG.GET_RSS_DATA:DEBUG=>Прочитали содержимое файла /home/fedorov/mypy/dataeng/fin-prj-01/data/lenta.ru|rss|/1672159374.json. Кол-во записей: 200<=1367093449.py->feedfile_to_pandas[19]
# 2022-12-27 19:45:36,781:DEBUG.GET_RSS_DATA:DEBUG=>Из файла /home/fedorov/mypy/dataeng/fin-prj-01/data/lenta.ru|rss|/1672159374.json получили таблицу, кол-во строк 200.<=1367093449.py->feedfile_to_pandas[27]
# 2022-12-27 19:45:36,785:DEBUG.GET_RSS_DATA:DEBUG=>Таблица для файла:1672159374.json, строк:200, нач.:Tue, 27 Dec 2022 19:39:23 +0300 Один из пострадавш, кон.:Tue, 27 Dec 2022 13:03:00 +0300 В Минобороны расск<=1933949487.py->join_all_feedfiles_pandas_sql[22]
# 2022-12-27 19:45:36,791:DEBUG.GET_RSS_DATA:DEBUG=>Прочитали содержимое файла /home/fedorov/mypy/dataeng/fin-prj-01/data/lenta.ru|rss|/1672148150.json. Кол-во записей: 200<=1367093449.py->feedfile_to_pandas[19]
# 2022-12-27 19:45:36,798:DEBUG.GET_RSS_DATA:DEBUG=>Из файла /home/fedorov/mypy/dataeng/fin-prj-01/data/lenta.ru|rss|/1672148150.json получили таблицу, кол-во строк 200.<=1367093449.py->feedfile_to_pandas[27]
# 2022-12-27 19:45:36,802:DEBUG.GET_RSS_DATA:DEBUG=>Таблица для файла:1672148150.json, строк:200, нач.:Tue, 27 Dec 2022 16:32:04 +0300 На Западе указали , кон.:Tue, 27 Dec 2022 10:12:00 +0300 Задушившая трех де<=1933949487.py->join_all_feedfiles_pandas_sql[22]
# 2022-12-27 19:45:36,808:DEBUG.GET_RSS_DATA:DEBUG=>Прочитали содержимое файла /home/fedorov/mypy/dataeng/fin-prj-01/data/lenta.ru|rss|/1672126337.json. Кол-во записей: 200<=1367093449.py->feedfile_to_pandas[19]
# 2022-12-27 19:45:36,814:DEBUG.GET_RSS_DATA:DEBUG=>Из файла /home/fedorov/mypy/dataeng/fin-prj-01/data/lenta.ru|rss|/1672126337.json получили таблицу, кол-во строк 200.<=1367093449.py->feedfile_to_pandas[27]
# 2022-12-27 19:45:36,818:DEBUG.GET_RSS_DATA:DEBUG=>Таблица для файла:1672126337.json, строк:200, нач.: Tue, 27 Dec 2022 10:29:54 +0300 Российскую «Армат, кон.:Mon, 26 Dec 2022 18:47:00 +0300 Украина захотела п<=1933949487.py->join_all_feedfiles_pandas_sql[22]
# 2022-12-27 19:45:36,824:DEBUG.GET_RSS_DATA:DEBUG=>Прочитали содержимое файла /home/fedorov/mypy/dataeng/fin-prj-01/data/lenta.ru|rss|/1672120671.json. Кол-во записей: 200<=1367093449.py->feedfile_to_pandas[19]
# 2022-12-27 19:45:36,829:DEBUG.GET_RSS_DATA:DEBUG=>Из файла /home/fedorov/mypy/dataeng/fin-prj-01/data/lenta.ru|rss|/1672120671.json получили таблицу, кол-во строк 200.<=1367093449.py->feedfile_to_pandas[27]
# 2022-12-27 19:45:36,833:DEBUG.GET_RSS_DATA:DEBUG=>Таблица для файла:1672120671.json, строк:200, нач.:Tue, 27 Dec 2022 08:54:37 +0300 Лавров назвал усло, кон.:Mon, 26 Dec 2022 17:13:00 +0300 В кабинете главы Р<=1933949487.py->join_all_feedfiles_pandas_sql[22]
# 2022-12-27 19:45:36,839:DEBUG.GET_RSS_DATA:DEBUG=>Прочитали содержимое файла /home/fedorov/mypy/dataeng/fin-prj-01/data/lenta.ru|rss|/1672082924.json. Кол-во записей: 200<=1367093449.py->feedfile_to_pandas[19]
# 2022-12-27 19:45:36,845:DEBUG.GET_RSS_DATA:DEBUG=>Из файла /home/fedorov/mypy/dataeng/fin-prj-01/data/lenta.ru|rss|/1672082924.json получили таблицу, кол-во строк 200.<=1367093449.py->feedfile_to_pandas[27]
# 2022-12-27 19:45:36,848:DEBUG.GET_RSS_DATA:DEBUG=>Таблица для файла:1672082924.json, строк:200, нач.:Mon, 26 Dec 2022 22:15:00 +0300 Песков оценил веро, кон.:Mon, 26 Dec 2022 14:14:00 +0300 В ЛНР рассказали о<=1933949487.py->join_all_feedfiles_pandas_sql[22]
# 2022-12-27 19:45:36,855:DEBUG.GET_RSS_DATA:DEBUG=>Прочитали содержимое файла /home/fedorov/mypy/dataeng/fin-prj-01/data/lenta.ru|rss|/1672080989.json. Кол-во записей: 200<=1367093449.py->feedfile_to_pandas[19]
# 2022-12-27 19:45:36,860:DEBUG.GET_RSS_DATA:DEBUG=>Из файла /home/fedorov/mypy/dataeng/fin-prj-01/data/lenta.ru|rss|/1672080989.json получили таблицу, кол-во строк 200.<=1367093449.py->feedfile_to_pandas[27]
# 2022-12-27 19:45:36,864:DEBUG.GET_RSS_DATA:DEBUG=>Таблица для файла:1672080989.json, строк:200, нач.: Mon, 26 Dec 2022 21:45:00 +0300 Медведев опублико, кон.:Mon, 26 Dec 2022 14:05:00 +0300 Неизвестный изреза<=1933949487.py->join_all_feedfiles_pandas_sql[22]
# 2022-12-27 19:45:36,871:DEBUG.GET_RSS_DATA:DEBUG=>Прочитали содержимое файла /home/fedorov/mypy/dataeng/fin-prj-01/data/lenta.ru|rss|/1672080885.json. Кол-во записей: 200<=1367093449.py->feedfile_to_pandas[19]
# 2022-12-27 19:45:36,876:DEBUG.GET_RSS_DATA:DEBUG=>Из файла /home/fedorov/mypy/dataeng/fin-prj-01/data/lenta.ru|rss|/1672080885.json получили таблицу, кол-во строк 200.<=1367093449.py->feedfile_to_pandas[27]
# 2022-12-27 19:45:36,880:DEBUG.GET_RSS_DATA:DEBUG=>Таблица для файла:1672080885.json, строк:200, нач.: Mon, 26 Dec 2022 21:45:00 +0300 Медведев опублико, кон.:Mon, 26 Dec 2022 14:05:00 +0300 Неизвестный изреза<=1933949487.py->join_all_feedfiles_pandas_sql[22]
# 2022-12-27 19:45:36,886:DEBUG.GET_RSS_DATA:DEBUG=>Прочитали содержимое файла /home/fedorov/mypy/dataeng/fin-prj-01/data/lenta.ru|rss|/1672080849.json. Кол-во записей: 200<=1367093449.py->feedfile_to_pandas[19]
# 2022-12-27 19:45:36,891:DEBUG.GET_RSS_DATA:DEBUG=>Из файла /home/fedorov/mypy/dataeng/fin-prj-01/data/lenta.ru|rss|/1672080849.json получили таблицу, кол-во строк 200.<=1367093449.py->feedfile_to_pandas[27]
# 2022-12-27 19:45:36,895:DEBUG.GET_RSS_DATA:DEBUG=>Таблица для файла:1672080849.json, строк:200, нач.: Mon, 26 Dec 2022 21:45:00 +0300 Медведев опублико, кон.:Mon, 26 Dec 2022 14:05:00 +0300 Неизвестный изреза<=1933949487.py->join_all_feedfiles_pandas_sql[22]
# 2022-12-27 19:45:36,897:DEBUG.GET_RSS_DATA:DEBUG=>Сформировали сводную таблицу для файлов в /home/fedorov/mypy/dataeng/fin-prj-01/data/lenta.ru|rss|. Кол-во строк: 2000<=1933949487.py->join_all_feedfiles_pandas_sql[29]
# 2022-12-27 19:45:36,911:DEBUG.GET_RSS_DATA:DEBUG=>После удаления дубликатов: кол-во строк: 623<=1933949487.py->join_all_feedfiles_pandas_sql[31]
# 2022-12-27 19:45:37,113:DEBUG.GET_RSS_DATA:DEBUG=>Добавлено в БД в таблицу: lenta.ru|rss|<=1933949487.py->join_all_feedfiles_pandas_sql[35]
# 2022-12-27 19:45:37,114:DEBUG.GET_RSS_DATA:DEBUG=>Прочитали директорию /home/fedorov/mypy/dataeng/fin-prj-01/data/www.vedomosti.ru|rss|news. Кол-во файлов: 9. Список: ['1672159532.json', '1672159375.json', '1672148152.json', '1672126338.json', '1672120672.json', '1672082925.json', '1672080990.json', '1672080886.json', '1672080850.json']<=1933949487.py->join_all_feedfiles_pandas_sql[11]
# 2022-12-27 19:45:37,118:DEBUG.GET_RSS_DATA:DEBUG=>Прочитали содержимое файла /home/fedorov/mypy/dataeng/fin-prj-01/data/www.vedomosti.ru|rss|news/1672159532.json. Кол-во записей: 200<=1367093449.py->feedfile_to_pandas[19]
# 2022-12-27 19:45:37,122:DEBUG.GET_RSS_DATA:DEBUG=>Из файла /home/fedorov/mypy/dataeng/fin-prj-01/data/www.vedomosti.ru|rss|news/1672159532.json получили таблицу, кол-во строк 200.<=1367093449.py->feedfile_to_pandas[27]
# 2022-12-27 19:45:37,125:DEBUG.GET_RSS_DATA:DEBUG=>Таблица для файла:1672159532.json, строк:200, нач.:Tue, 27 Dec 2022 19:32:02 +0300 KazanExpress может, кон.:Fri, 23 Dec 2022 20:38:48 +0300 В Грузии подтверди<=1933949487.py->join_all_feedfiles_pandas_sql[22]
# 2022-12-27 19:45:37,126:DEBUG.GET_RSS_DATA:DEBUG=>Начальная инициализация пустой таблицы<=1933949487.py->join_all_feedfiles_pandas_sql[26]
# 2022-12-27 19:45:37,130:DEBUG.GET_RSS_DATA:DEBUG=>Прочитали содержимое файла /home/fedorov/mypy/dataeng/fin-prj-01/data/www.vedomosti.ru|rss|news/1672159375.json. Кол-во записей: 200<=1367093449.py->feedfile_to_pandas[19]
# 2022-12-27 19:45:37,135:DEBUG.GET_RSS_DATA:DEBUG=>Из файла /home/fedorov/mypy/dataeng/fin-prj-01/data/www.vedomosti.ru|rss|news/1672159375.json получили таблицу, кол-во строк 200.<=1367093449.py->feedfile_to_pandas[27]
# 2022-12-27 19:45:37,138:DEBUG.GET_RSS_DATA:DEBUG=>Таблица для файла:1672159375.json, строк:200, нач.:Tue, 27 Dec 2022 19:32:02 +0300 KazanExpress может, кон.:Fri, 23 Dec 2022 20:38:48 +0300 В Грузии подтверди<=1933949487.py->join_all_feedfiles_pandas_sql[22]
# 2022-12-27 19:45:37,142:DEBUG.GET_RSS_DATA:DEBUG=>Прочитали содержимое файла /home/fedorov/mypy/dataeng/fin-prj-01/data/www.vedomosti.ru|rss|news/1672148152.json. Кол-во записей: 200<=1367093449.py->feedfile_to_pandas[19]
# 2022-12-27 19:45:37,146:DEBUG.GET_RSS_DATA:DEBUG=>Из файла /home/fedorov/mypy/dataeng/fin-prj-01/data/www.vedomosti.ru|rss|news/1672148152.json получили таблицу, кол-во строк 200.<=1367093449.py->feedfile_to_pandas[27]
# 2022-12-27 19:45:37,150:DEBUG.GET_RSS_DATA:DEBUG=>Таблица для файла:1672148152.json, строк:200, нач.:Tue, 27 Dec 2022 16:24:28 +0300 МИД подтвердил вып, кон.:Fri, 23 Dec 2022 16:40:54 +0300 МИД Азербайджана п<=1933949487.py->join_all_feedfiles_pandas_sql[22]
# 2022-12-27 19:45:37,154:DEBUG.GET_RSS_DATA:DEBUG=>Прочитали содержимое файла /home/fedorov/mypy/dataeng/fin-prj-01/data/www.vedomosti.ru|rss|news/1672126338.json. Кол-во записей: 200<=1367093449.py->feedfile_to_pandas[19]
# 2022-12-27 19:45:37,158:DEBUG.GET_RSS_DATA:DEBUG=>Из файла /home/fedorov/mypy/dataeng/fin-prj-01/data/www.vedomosti.ru|rss|news/1672126338.json получили таблицу, кол-во строк 200.<=1367093449.py->feedfile_to_pandas[27]
# 2022-12-27 19:45:37,162:DEBUG.GET_RSS_DATA:DEBUG=>Таблица для файла:1672126338.json, строк:200, нач.: Tue, 27 Dec 2022 10:20:55 +0300 ВТБ закрыл сделку, кон.:Fri, 23 Dec 2022 10:44:38 +0300 Жители новых регио<=1933949487.py->join_all_feedfiles_pandas_sql[22]
# 2022-12-27 19:45:37,165:DEBUG.GET_RSS_DATA:DEBUG=>Прочитали содержимое файла /home/fedorov/mypy/dataeng/fin-prj-01/data/www.vedomosti.ru|rss|news/1672120672.json. Кол-во записей: 200<=1367093449.py->feedfile_to_pandas[19]
# 2022-12-27 19:45:37,168:DEBUG.GET_RSS_DATA:DEBUG=>Из файла /home/fedorov/mypy/dataeng/fin-prj-01/data/www.vedomosti.ru|rss|news/1672120672.json получили таблицу, кол-во строк 200.<=1367093449.py->feedfile_to_pandas[27]
# 2022-12-27 19:45:37,171:DEBUG.GET_RSS_DATA:DEBUG=>Таблица для файла:1672120672.json, строк:200, нач.:Tue, 27 Dec 2022 08:45:58 +0300 Китай упростит выд, кон.:Fri, 23 Dec 2022 09:49:39 +0300 Жена Рогозина опро<=1933949487.py->join_all_feedfiles_pandas_sql[22]
# 2022-12-27 19:45:37,175:DEBUG.GET_RSS_DATA:DEBUG=>Прочитали содержимое файла /home/fedorov/mypy/dataeng/fin-prj-01/data/www.vedomosti.ru|rss|news/1672082925.json. Кол-во записей: 200<=1367093449.py->feedfile_to_pandas[19]
# 2022-12-27 19:45:37,180:DEBUG.GET_RSS_DATA:DEBUG=>Из файла /home/fedorov/mypy/dataeng/fin-prj-01/data/www.vedomosti.ru|rss|news/1672082925.json получили таблицу, кол-во строк 200.<=1367093449.py->feedfile_to_pandas[27]
# 2022-12-27 19:45:37,183:DEBUG.GET_RSS_DATA:DEBUG=>Таблица для файла:1672082925.json, строк:200, нач.:Mon, 26 Dec 2022 22:09:01 +0300 Медведев спрогнози, кон.:Fri, 23 Dec 2022 08:37:10 +0300 Посол Индии заявил<=1933949487.py->join_all_feedfiles_pandas_sql[22]
# 2022-12-27 19:45:37,187:DEBUG.GET_RSS_DATA:DEBUG=>Прочитали содержимое файла /home/fedorov/mypy/dataeng/fin-prj-01/data/www.vedomosti.ru|rss|news/1672080990.json. Кол-во записей: 200<=1367093449.py->feedfile_to_pandas[19]
# 2022-12-27 19:45:37,192:DEBUG.GET_RSS_DATA:DEBUG=>Из файла /home/fedorov/mypy/dataeng/fin-prj-01/data/www.vedomosti.ru|rss|news/1672080990.json получили таблицу, кол-во строк 200.<=1367093449.py->feedfile_to_pandas[27]
# 2022-12-27 19:45:37,196:DEBUG.GET_RSS_DATA:DEBUG=>Таблица для файла:1672080990.json, строк:200, нач.:Mon, 26 Dec 2022 21:50:02 +0300 На Камчатке началс, кон.:Fri, 23 Dec 2022 08:17:27 +0300 Новак: Россия запр<=1933949487.py->join_all_feedfiles_pandas_sql[22]
# 2022-12-27 19:45:37,199:DEBUG.GET_RSS_DATA:DEBUG=>Прочитали содержимое файла /home/fedorov/mypy/dataeng/fin-prj-01/data/www.vedomosti.ru|rss|news/1672080886.json. Кол-во записей: 200<=1367093449.py->feedfile_to_pandas[19]
# 2022-12-27 19:45:37,204:DEBUG.GET_RSS_DATA:DEBUG=>Из файла /home/fedorov/mypy/dataeng/fin-prj-01/data/www.vedomosti.ru|rss|news/1672080886.json получили таблицу, кол-во строк 200.<=1367093449.py->feedfile_to_pandas[27]
# 2022-12-27 19:45:37,208:DEBUG.GET_RSS_DATA:DEBUG=>Таблица для файла:1672080886.json, строк:200, нач.:Mon, 26 Dec 2022 21:50:02 +0300 На Камчатке началс, кон.:Fri, 23 Dec 2022 08:17:27 +0300 Новак: Россия запр<=1933949487.py->join_all_feedfiles_pandas_sql[22]
# 2022-12-27 19:45:37,211:DEBUG.GET_RSS_DATA:DEBUG=>Прочитали содержимое файла /home/fedorov/mypy/dataeng/fin-prj-01/data/www.vedomosti.ru|rss|news/1672080850.json. Кол-во записей: 200<=1367093449.py->feedfile_to_pandas[19]
# 2022-12-27 19:45:37,216:DEBUG.GET_RSS_DATA:DEBUG=>Из файла /home/fedorov/mypy/dataeng/fin-prj-01/data/www.vedomosti.ru|rss|news/1672080850.json получили таблицу, кол-во строк 200.<=1367093449.py->feedfile_to_pandas[27]
# 2022-12-27 19:45:37,219:DEBUG.GET_RSS_DATA:DEBUG=>Таблица для файла:1672080850.json, строк:200, нач.:Mon, 26 Dec 2022 21:50:02 +0300 На Камчатке началс, кон.:Fri, 23 Dec 2022 08:17:27 +0300 Новак: Россия запр<=1933949487.py->join_all_feedfiles_pandas_sql[22]
# 2022-12-27 19:45:37,220:DEBUG.GET_RSS_DATA:DEBUG=>Сформировали сводную таблицу для файлов в /home/fedorov/mypy/dataeng/fin-prj-01/data/www.vedomosti.ru|rss|news. Кол-во строк: 2000<=1933949487.py->join_all_feedfiles_pandas_sql[29]
# 2022-12-27 19:45:37,227:DEBUG.GET_RSS_DATA:DEBUG=>После удаления дубликатов: кол-во строк: 271<=1933949487.py->join_all_feedfiles_pandas_sql[31]
# 2022-12-27 19:45:37,656:DEBUG.GET_RSS_DATA:DEBUG=>Добавлено в БД в таблицу: www.vedomosti.ru|rss|news<=1933949487.py->join_all_feedfiles_pandas_sql[35]
# 2022-12-27 19:45:37,659:DEBUG.GET_RSS_DATA:DEBUG=>Прочитали директорию /home/fedorov/mypy/dataeng/fin-prj-01/data/tass.ru|rss|v2.xml. Кол-во файлов: 9. Список: ['1672159533.json', '1672159375.json', '1672148152.json', '1672126338.json', '1672120672.json', '1672082925.json', '1672080990.json', '1672080886.json', '1672080850.json']<=1933949487.py->join_all_feedfiles_pandas_sql[11]
# 2022-12-27 19:45:37,662:DEBUG.GET_RSS_DATA:DEBUG=>Прочитали содержимое файла /home/fedorov/mypy/dataeng/fin-prj-01/data/tass.ru|rss|v2.xml/1672159533.json. Кол-во записей: 98<=1367093449.py->feedfile_to_pandas[19]
# 2022-12-27 19:45:37,667:DEBUG.GET_RSS_DATA:DEBUG=>Из файла /home/fedorov/mypy/dataeng/fin-prj-01/data/tass.ru|rss|v2.xml/1672159533.json получили таблицу, кол-во строк 98.<=1367093449.py->feedfile_to_pandas[27]
# 2022-12-27 19:45:37,671:DEBUG.GET_RSS_DATA:DEBUG=>Таблица для файла:1672159533.json, строк:98, нач.:Tue, 27 Dec 2022 19:38:20 +0300 В Астрахани ликвид, кон.:Tue, 27 Dec 2022 17:24:24 +0300 Книгу о битве за Л<=1933949487.py->join_all_feedfiles_pandas_sql[22]
# 2022-12-27 19:45:37,672:DEBUG.GET_RSS_DATA:DEBUG=>Начальная инициализация пустой таблицы<=1933949487.py->join_all_feedfiles_pandas_sql[26]
# 2022-12-27 19:45:37,676:DEBUG.GET_RSS_DATA:DEBUG=>Прочитали содержимое файла /home/fedorov/mypy/dataeng/fin-prj-01/data/tass.ru|rss|v2.xml/1672159375.json. Кол-во записей: 98<=1367093449.py->feedfile_to_pandas[19]
# 2022-12-27 19:45:37,681:DEBUG.GET_RSS_DATA:DEBUG=>Из файла /home/fedorov/mypy/dataeng/fin-prj-01/data/tass.ru|rss|v2.xml/1672159375.json получили таблицу, кол-во строк 98.<=1367093449.py->feedfile_to_pandas[27]
# 2022-12-27 19:45:37,685:DEBUG.GET_RSS_DATA:DEBUG=>Таблица для файла:1672159375.json, строк:98, нач.:Tue, 27 Dec 2022 19:38:20 +0300 В Астрахани ликвид, кон.:Tue, 27 Dec 2022 17:24:24 +0300 Книгу о битве за Л<=1933949487.py->join_all_feedfiles_pandas_sql[22]
# 2022-12-27 19:45:37,688:DEBUG.GET_RSS_DATA:DEBUG=>Прочитали содержимое файла /home/fedorov/mypy/dataeng/fin-prj-01/data/tass.ru|rss|v2.xml/1672148152.json. Кол-во записей: 100<=1367093449.py->feedfile_to_pandas[19]
# 2022-12-27 19:45:37,692:DEBUG.GET_RSS_DATA:DEBUG=>Из файла /home/fedorov/mypy/dataeng/fin-prj-01/data/tass.ru|rss|v2.xml/1672148152.json получили таблицу, кол-во строк 100.<=1367093449.py->feedfile_to_pandas[27]
# 2022-12-27 19:45:37,694:DEBUG.GET_RSS_DATA:DEBUG=>Таблица для файла:1672148152.json, строк:100, нач.:Tue, 27 Dec 2022 16:32:20 +0300 Вучич обвинил межд, кон.:Tue, 27 Dec 2022 15:07:59 +0300 Сетевикам могут во<=1933949487.py->join_all_feedfiles_pandas_sql[22]
# 2022-12-27 19:45:37,697:DEBUG.GET_RSS_DATA:DEBUG=>Прочитали содержимое файла /home/fedorov/mypy/dataeng/fin-prj-01/data/tass.ru|rss|v2.xml/1672126338.json. Кол-во записей: 96<=1367093449.py->feedfile_to_pandas[19]
# 2022-12-27 19:45:37,700:DEBUG.GET_RSS_DATA:DEBUG=>Из файла /home/fedorov/mypy/dataeng/fin-prj-01/data/tass.ru|rss|v2.xml/1672126338.json получили таблицу, кол-во строк 96.<=1367093449.py->feedfile_to_pandas[27]
# 2022-12-27 19:45:37,707:DEBUG.GET_RSS_DATA:DEBUG=>Таблица для файла:1672126338.json, строк:96, нач.:Tue, 27 Dec 2022 10:27:39 +0300 На углубление русе, кон.:Tue, 27 Dec 2022 08:23:17 +0300 Топ-3 импортеров р<=1933949487.py->join_all_feedfiles_pandas_sql[22]
# 2022-12-27 19:45:37,710:DEBUG.GET_RSS_DATA:DEBUG=>Прочитали содержимое файла /home/fedorov/mypy/dataeng/fin-prj-01/data/tass.ru|rss|v2.xml/1672120672.json. Кол-во записей: 99<=1367093449.py->feedfile_to_pandas[19]
# 2022-12-27 19:45:37,713:DEBUG.GET_RSS_DATA:DEBUG=>Из файла /home/fedorov/mypy/dataeng/fin-prj-01/data/tass.ru|rss|v2.xml/1672120672.json получили таблицу, кол-во строк 99.<=1367093449.py->feedfile_to_pandas[27]
# 2022-12-27 19:45:37,716:DEBUG.GET_RSS_DATA:DEBUG=>Таблица для файла:1672120672.json, строк:99, нач.:Tue, 27 Dec 2022 08:55:06 +0300 Япония с 30 декабр, кон.:Tue, 27 Dec 2022 04:16:56 +0300 Посол РФ в Мексике<=1933949487.py->join_all_feedfiles_pandas_sql[22]
# 2022-12-27 19:45:37,718:DEBUG.GET_RSS_DATA:DEBUG=>Прочитали содержимое файла /home/fedorov/mypy/dataeng/fin-prj-01/data/tass.ru|rss|v2.xml/1672082925.json. Кол-во записей: 99<=1367093449.py->feedfile_to_pandas[19]
# 2022-12-27 19:45:37,721:DEBUG.GET_RSS_DATA:DEBUG=>Из файла /home/fedorov/mypy/dataeng/fin-prj-01/data/tass.ru|rss|v2.xml/1672082925.json получили таблицу, кол-во строк 99.<=1367093449.py->feedfile_to_pandas[27]
# 2022-12-27 19:45:37,724:DEBUG.GET_RSS_DATA:DEBUG=>Таблица для файла:1672082925.json, строк:99, нач.:Mon, 26 Dec 2022 22:23:30 +0300 Власти Изюма переи, кон.:Mon, 26 Dec 2022 19:00:00 +0300 Гендиректор ФИОП: <=1933949487.py->join_all_feedfiles_pandas_sql[22]
# 2022-12-27 19:45:37,728:DEBUG.GET_RSS_DATA:DEBUG=>Прочитали содержимое файла /home/fedorov/mypy/dataeng/fin-prj-01/data/tass.ru|rss|v2.xml/1672080990.json. Кол-во записей: 100<=1367093449.py->feedfile_to_pandas[19]
# 2022-12-27 19:45:37,740:DEBUG.GET_RSS_DATA:DEBUG=>Из файла /home/fedorov/mypy/dataeng/fin-prj-01/data/tass.ru|rss|v2.xml/1672080990.json получили таблицу, кол-во строк 100.<=1367093449.py->feedfile_to_pandas[27]
# 2022-12-27 19:45:37,744:DEBUG.GET_RSS_DATA:DEBUG=>Таблица для файла:1672080990.json, строк:100, нач.:Mon, 26 Dec 2022 21:51:20 +0300 Пушилин сообщил об, кон.:Mon, 26 Dec 2022 18:37:02 +0300 Путин утвердил пор<=1933949487.py->join_all_feedfiles_pandas_sql[22]
# 2022-12-27 19:45:37,747:DEBUG.GET_RSS_DATA:DEBUG=>Прочитали содержимое файла /home/fedorov/mypy/dataeng/fin-prj-01/data/tass.ru|rss|v2.xml/1672080886.json. Кол-во записей: 100<=1367093449.py->feedfile_to_pandas[19]
# 2022-12-27 19:45:37,751:DEBUG.GET_RSS_DATA:DEBUG=>Из файла /home/fedorov/mypy/dataeng/fin-prj-01/data/tass.ru|rss|v2.xml/1672080886.json получили таблицу, кол-во строк 100.<=1367093449.py->feedfile_to_pandas[27]
# 2022-12-27 19:45:37,755:DEBUG.GET_RSS_DATA:DEBUG=>Таблица для файла:1672080886.json, строк:100, нач.:Mon, 26 Dec 2022 21:50:13 +0300 ЦБ в феврале может, кон.:Mon, 26 Dec 2022 18:36:13 +0300 В Коми спасатели н<=1933949487.py->join_all_feedfiles_pandas_sql[22]
# 2022-12-27 19:45:37,758:DEBUG.GET_RSS_DATA:DEBUG=>Прочитали содержимое файла /home/fedorov/mypy/dataeng/fin-prj-01/data/tass.ru|rss|v2.xml/1672080850.json. Кол-во записей: 100<=1367093449.py->feedfile_to_pandas[19]
# 2022-12-27 19:45:37,762:DEBUG.GET_RSS_DATA:DEBUG=>Из файла /home/fedorov/mypy/dataeng/fin-prj-01/data/tass.ru|rss|v2.xml/1672080850.json получили таблицу, кол-во строк 100.<=1367093449.py->feedfile_to_pandas[27]
# 2022-12-27 19:45:37,766:DEBUG.GET_RSS_DATA:DEBUG=>Таблица для файла:1672080850.json, строк:100, нач.:Mon, 26 Dec 2022 21:50:13 +0300 ЦБ в феврале может, кон.:Mon, 26 Dec 2022 18:36:13 +0300 В Коми спасатели н<=1933949487.py->join_all_feedfiles_pandas_sql[22]
# 2022-12-27 19:45:37,767:DEBUG.GET_RSS_DATA:DEBUG=>Сформировали сводную таблицу для файлов в /home/fedorov/mypy/dataeng/fin-prj-01/data/tass.ru|rss|v2.xml. Кол-во строк: 988<=1933949487.py->join_all_feedfiles_pandas_sql[29]
# 2022-12-27 19:45:37,774:DEBUG.GET_RSS_DATA:DEBUG=>После удаления дубликатов: кол-во строк: 481<=1933949487.py->join_all_feedfiles_pandas_sql[31]
# 2022-12-27 19:45:37,951:DEBUG.GET_RSS_DATA:DEBUG=>Добавлено в БД в таблицу: tass.ru|rss|v2.xml<=1933949487.py->join_all_feedfiles_pandas_sql[35]
# 2022-12-27 19:45:37,953:DEBUG.GET_RSS_DATA:DEBUG=>Прочитали директорию /home/fedorov/mypy/dataeng/fin-prj-01/data/ria.ru|export|rss2|archive|index.xml. Кол-во файлов: 9. Список: ['1672159533.json', '1672159376.json', '1672148153.json', '1672126339.json', '1672120672.json', '1672082926.json', '1672080991.json', '1672080886.json', '1672080851.json']<=1933949487.py->join_all_feedfiles_pandas_sql[11]
# 2022-12-27 19:45:37,956:DEBUG.GET_RSS_DATA:DEBUG=>Прочитали содержимое файла /home/fedorov/mypy/dataeng/fin-prj-01/data/ria.ru|export|rss2|archive|index.xml/1672159533.json. Кол-во записей: 100<=1367093449.py->feedfile_to_pandas[19]
# 2022-12-27 19:45:37,961:DEBUG.GET_RSS_DATA:DEBUG=>Из файла /home/fedorov/mypy/dataeng/fin-prj-01/data/ria.ru|export|rss2|archive|index.xml/1672159533.json получили таблицу, кол-во строк 100.<=1367093449.py->feedfile_to_pandas[27]
# 2022-12-27 19:45:37,965:DEBUG.GET_RSS_DATA:DEBUG=>Таблица для файла:1672159533.json, строк:100, нач.:Tue, 27 Dec 2022 19:42:14 +0300 В московских аэроп, кон.:Tue, 27 Dec 2022 15:25:47 +0300 Украинские войска <=1933949487.py->join_all_feedfiles_pandas_sql[22]
# 2022-12-27 19:45:37,966:DEBUG.GET_RSS_DATA:DEBUG=>Начальная инициализация пустой таблицы<=1933949487.py->join_all_feedfiles_pandas_sql[26]
# 2022-12-27 19:45:37,969:DEBUG.GET_RSS_DATA:DEBUG=>Прочитали содержимое файла /home/fedorov/mypy/dataeng/fin-prj-01/data/ria.ru|export|rss2|archive|index.xml/1672159376.json. Кол-во записей: 100<=1367093449.py->feedfile_to_pandas[19]
# 2022-12-27 19:45:37,973:DEBUG.GET_RSS_DATA:DEBUG=>Из файла /home/fedorov/mypy/dataeng/fin-prj-01/data/ria.ru|export|rss2|archive|index.xml/1672159376.json получили таблицу, кол-во строк 100.<=1367093449.py->feedfile_to_pandas[27]
# 2022-12-27 19:45:37,977:DEBUG.GET_RSS_DATA:DEBUG=>Таблица для файла:1672159376.json, строк:100, нач.:Tue, 27 Dec 2022 19:38:53 +0300 Ozon опроверг сооб, кон.:Tue, 27 Dec 2022 15:22:11 +0300 Водителю маршрутки<=1933949487.py->join_all_feedfiles_pandas_sql[22]
# 2022-12-27 19:45:37,980:DEBUG.GET_RSS_DATA:DEBUG=>Прочитали содержимое файла /home/fedorov/mypy/dataeng/fin-prj-01/data/ria.ru|export|rss2|archive|index.xml/1672148153.json. Кол-во записей: 99<=1367093449.py->feedfile_to_pandas[19]
# 2022-12-27 19:45:37,984:DEBUG.GET_RSS_DATA:DEBUG=>Из файла /home/fedorov/mypy/dataeng/fin-prj-01/data/ria.ru|export|rss2|archive|index.xml/1672148153.json получили таблицу, кол-во строк 99.<=1367093449.py->feedfile_to_pandas[27]
# 2022-12-27 19:45:37,988:DEBUG.GET_RSS_DATA:DEBUG=>Таблица для файла:1672148153.json, строк:99, нач.:Tue, 27 Dec 2022 16:34:01 +0300 Дед Мороз и Снегур, кон.:Tue, 27 Dec 2022 12:51:38 +0300 Эксперт рассказал,<=1933949487.py->join_all_feedfiles_pandas_sql[22]
# 2022-12-27 19:45:37,991:DEBUG.GET_RSS_DATA:DEBUG=>Прочитали содержимое файла /home/fedorov/mypy/dataeng/fin-prj-01/data/ria.ru|export|rss2|archive|index.xml/1672126339.json. Кол-во записей: 98<=1367093449.py->feedfile_to_pandas[19]
# 2022-12-27 19:45:37,995:DEBUG.GET_RSS_DATA:DEBUG=>Из файла /home/fedorov/mypy/dataeng/fin-prj-01/data/ria.ru|export|rss2|archive|index.xml/1672126339.json получили таблицу, кол-во строк 98.<=1367093449.py->feedfile_to_pandas[27]
# 2022-12-27 19:45:37,999:DEBUG.GET_RSS_DATA:DEBUG=>Таблица для файла:1672126339.json, строк:98, нач.:Tue, 27 Dec 2022 10:30:03 +0300 Аферисты обманули , кон.:Mon, 26 Dec 2022 22:36:46 +0300 Спецоперация, 26 д<=1933949487.py->join_all_feedfiles_pandas_sql[22]
# 2022-12-27 19:45:38,004:DEBUG.GET_RSS_DATA:DEBUG=>Прочитали содержимое файла /home/fedorov/mypy/dataeng/fin-prj-01/data/ria.ru|export|rss2|archive|index.xml/1672120672.json. Кол-во записей: 98<=1367093449.py->feedfile_to_pandas[19]
# 2022-12-27 19:45:38,009:DEBUG.GET_RSS_DATA:DEBUG=>Из файла /home/fedorov/mypy/dataeng/fin-prj-01/data/ria.ru|export|rss2|archive|index.xml/1672120672.json получили таблицу, кол-во строк 98.<=1367093449.py->feedfile_to_pandas[27]
# 2022-12-27 19:45:38,013:DEBUG.GET_RSS_DATA:DEBUG=>Таблица для файла:1672120672.json, строк:98, нач.:Tue, 27 Dec 2022 08:56:03 +0300 Китай упростит про, кон.: Mon, 26 Dec 2022 20:08:49 +0300 Суд оставил журна<=1933949487.py->join_all_feedfiles_pandas_sql[22]
# 2022-12-27 19:45:38,017:DEBUG.GET_RSS_DATA:DEBUG=>Прочитали содержимое файла /home/fedorov/mypy/dataeng/fin-prj-01/data/ria.ru|export|rss2|archive|index.xml/1672082926.json. Кол-во записей: 100<=1367093449.py->feedfile_to_pandas[19]
# 2022-12-27 19:45:38,021:DEBUG.GET_RSS_DATA:DEBUG=>Из файла /home/fedorov/mypy/dataeng/fin-prj-01/data/ria.ru|export|rss2|archive|index.xml/1672082926.json получили таблицу, кол-во строк 100.<=1367093449.py->feedfile_to_pandas[27]
# 2022-12-27 19:45:38,025:DEBUG.GET_RSS_DATA:DEBUG=>Таблица для файла:1672082926.json, строк:100, нач.:Mon, 26 Dec 2022 22:15:15 +0300 В Кремле прокоммен, кон.:Mon, 26 Dec 2022 16:41:13 +0300 В Орловской област<=1933949487.py->join_all_feedfiles_pandas_sql[22]
# 2022-12-27 19:45:38,028:DEBUG.GET_RSS_DATA:DEBUG=>Прочитали содержимое файла /home/fedorov/mypy/dataeng/fin-prj-01/data/ria.ru|export|rss2|archive|index.xml/1672080991.json. Кол-во записей: 100<=1367093449.py->feedfile_to_pandas[19]
# 2022-12-27 19:45:38,033:DEBUG.GET_RSS_DATA:DEBUG=>Из файла /home/fedorov/mypy/dataeng/fin-prj-01/data/ria.ru|export|rss2|archive|index.xml/1672080991.json получили таблицу, кол-во строк 100.<=1367093449.py->feedfile_to_pandas[27]
# 2022-12-27 19:45:38,037:DEBUG.GET_RSS_DATA:DEBUG=>Таблица для файла:1672080991.json, строк:100, нач.:Mon, 26 Dec 2022 21:55:55 +0300 Медведев сделал "ф, кон.:Mon, 26 Dec 2022 16:36:30 +0300 Токаев призвал кол<=1933949487.py->join_all_feedfiles_pandas_sql[22]
# 2022-12-27 19:45:38,040:DEBUG.GET_RSS_DATA:DEBUG=>Прочитали содержимое файла /home/fedorov/mypy/dataeng/fin-prj-01/data/ria.ru|export|rss2|archive|index.xml/1672080886.json. Кол-во записей: 100<=1367093449.py->feedfile_to_pandas[19]
# 2022-12-27 19:45:38,044:DEBUG.GET_RSS_DATA:DEBUG=>Из файла /home/fedorov/mypy/dataeng/fin-prj-01/data/ria.ru|export|rss2|archive|index.xml/1672080886.json получили таблицу, кол-во строк 100.<=1367093449.py->feedfile_to_pandas[27]
# 2022-12-27 19:45:38,048:DEBUG.GET_RSS_DATA:DEBUG=>Таблица для файла:1672080886.json, строк:100, нач.:Mon, 26 Dec 2022 21:39:37 +0300 ОАК выделят 900 ми, кон.:Mon, 26 Dec 2022 16:34:13 +0300 Медведев заявил об<=1933949487.py->join_all_feedfiles_pandas_sql[22]
# 2022-12-27 19:45:38,051:DEBUG.GET_RSS_DATA:DEBUG=>Прочитали содержимое файла /home/fedorov/mypy/dataeng/fin-prj-01/data/ria.ru|export|rss2|archive|index.xml/1672080851.json. Кол-во записей: 100<=1367093449.py->feedfile_to_pandas[19]
# 2022-12-27 19:45:38,055:DEBUG.GET_RSS_DATA:DEBUG=>Из файла /home/fedorov/mypy/dataeng/fin-prj-01/data/ria.ru|export|rss2|archive|index.xml/1672080851.json получили таблицу, кол-во строк 100.<=1367093449.py->feedfile_to_pandas[27]
# 2022-12-27 19:45:38,059:DEBUG.GET_RSS_DATA:DEBUG=>Таблица для файла:1672080851.json, строк:100, нач.:Mon, 26 Dec 2022 21:39:37 +0300 ОАК выделят 900 ми, кон.:Mon, 26 Dec 2022 16:34:13 +0300 Медведев заявил об<=1933949487.py->join_all_feedfiles_pandas_sql[22]
# 2022-12-27 19:45:38,061:DEBUG.GET_RSS_DATA:DEBUG=>Сформировали сводную таблицу для файлов в /home/fedorov/mypy/dataeng/fin-prj-01/data/ria.ru|export|rss2|archive|index.xml. Кол-во строк: 995<=1933949487.py->join_all_feedfiles_pandas_sql[29]
# 2022-12-27 19:45:38,066:DEBUG.GET_RSS_DATA:DEBUG=>После удаления дубликатов: кол-во строк: 375<=1933949487.py->join_all_feedfiles_pandas_sql[31]
# 2022-12-27 19:45:38,222:DEBUG.GET_RSS_DATA:DEBUG=>Добавлено в БД в таблицу: ria.ru|export|rss2|archive|index.xml<=1933949487.py->join_all_feedfiles_pandas_sql[35]
# 2022-12-27 19:45:38,223:DEBUG.GET_RSS_DATA:DEBUG=>Прочитали директорию /home/fedorov/mypy/dataeng/fin-prj-01/data/www.kommersant.ru|RSS|news.xml. Кол-во файлов: 9. Список: ['1672159534.json', '1672159376.json', '1672148235.json', '1672126339.json', '1672120673.json', '1672082927.json', '1672080991.json', '1672080887.json', '1672080852.json']<=1933949487.py->join_all_feedfiles_pandas_sql[11]
# 2022-12-27 19:45:38,230:DEBUG.GET_RSS_DATA:DEBUG=>Прочитали содержимое файла /home/fedorov/mypy/dataeng/fin-prj-01/data/www.kommersant.ru|RSS|news.xml/1672159534.json. Кол-во записей: 329<=1367093449.py->feedfile_to_pandas[19]
# 2022-12-27 19:45:38,237:DEBUG.GET_RSS_DATA:DEBUG=>Из файла /home/fedorov/mypy/dataeng/fin-prj-01/data/www.kommersant.ru|RSS|news.xml/1672159534.json получили таблицу, кол-во строк 329.<=1367093449.py->feedfile_to_pandas[27]
# 2022-12-27 19:45:38,241:DEBUG.GET_RSS_DATA:DEBUG=>Таблица для файла:1672159534.json, строк:329, нач.: Tue, 27 Dec 2022 19:36:52 +0300 Пробки в Москве д, кон.:Sun, 25 Dec 2022 00:37:05 +0300 В США зимний шторм<=1933949487.py->join_all_feedfiles_pandas_sql[22]
# 2022-12-27 19:45:38,242:DEBUG.GET_RSS_DATA:DEBUG=>Начальная инициализация пустой таблицы<=1933949487.py->join_all_feedfiles_pandas_sql[26]
# 2022-12-27 19:45:38,249:DEBUG.GET_RSS_DATA:DEBUG=>Прочитали содержимое файла /home/fedorov/mypy/dataeng/fin-prj-01/data/www.kommersant.ru|RSS|news.xml/1672159376.json. Кол-во записей: 329<=1367093449.py->feedfile_to_pandas[19]
# 2022-12-27 19:45:38,255:DEBUG.GET_RSS_DATA:DEBUG=>Из файла /home/fedorov/mypy/dataeng/fin-prj-01/data/www.kommersant.ru|RSS|news.xml/1672159376.json получили таблицу, кол-во строк 329.<=1367093449.py->feedfile_to_pandas[27]
# 2022-12-27 19:45:38,260:DEBUG.GET_RSS_DATA:DEBUG=>Таблица для файла:1672159376.json, строк:329, нач.: Tue, 27 Dec 2022 19:36:52 +0300 Пробки в Москве д, кон.:Sun, 25 Dec 2022 00:37:05 +0300 В США зимний шторм<=1933949487.py->join_all_feedfiles_pandas_sql[22]
# 2022-12-27 19:45:38,266:DEBUG.GET_RSS_DATA:DEBUG=>Прочитали содержимое файла /home/fedorov/mypy/dataeng/fin-prj-01/data/www.kommersant.ru|RSS|news.xml/1672148235.json. Кол-во записей: 302<=1367093449.py->feedfile_to_pandas[19]
# 2022-12-27 19:45:38,273:DEBUG.GET_RSS_DATA:DEBUG=>Из файла /home/fedorov/mypy/dataeng/fin-prj-01/data/www.kommersant.ru|RSS|news.xml/1672148235.json получили таблицу, кол-во строк 302.<=1367093449.py->feedfile_to_pandas[27]
# 2022-12-27 19:45:38,276:DEBUG.GET_RSS_DATA:DEBUG=>Таблица для файла:1672148235.json, строк:302, нач.:Tue, 27 Dec 2022 16:19:49 +0300 Горнолыжный курорт, кон.:Sun, 25 Dec 2022 00:37:05 +0300 В США зимний шторм<=1933949487.py->join_all_feedfiles_pandas_sql[22]
# 2022-12-27 19:45:38,282:DEBUG.GET_RSS_DATA:DEBUG=>Прочитали содержимое файла /home/fedorov/mypy/dataeng/fin-prj-01/data/www.kommersant.ru|RSS|news.xml/1672126339.json. Кол-во записей: 247<=1367093449.py->feedfile_to_pandas[19]
# 2022-12-27 19:45:38,288:DEBUG.GET_RSS_DATA:DEBUG=>Из файла /home/fedorov/mypy/dataeng/fin-prj-01/data/www.kommersant.ru|RSS|news.xml/1672126339.json получили таблицу, кол-во строк 247.<=1367093449.py->feedfile_to_pandas[27]
# 2022-12-27 19:45:38,292:DEBUG.GET_RSS_DATA:DEBUG=>Таблица для файла:1672126339.json, строк:247, нач.:Tue, 27 Dec 2022 10:20:08 +0300 Число погибших в р, кон.:Sun, 25 Dec 2022 00:37:05 +0300 В США зимний шторм<=1933949487.py->join_all_feedfiles_pandas_sql[22]
# 2022-12-27 19:45:38,298:DEBUG.GET_RSS_DATA:DEBUG=>Прочитали содержимое файла /home/fedorov/mypy/dataeng/fin-prj-01/data/www.kommersant.ru|RSS|news.xml/1672120673.json. Кол-во записей: 235<=1367093449.py->feedfile_to_pandas[19]
# 2022-12-27 19:45:38,303:DEBUG.GET_RSS_DATA:DEBUG=>Из файла /home/fedorov/mypy/dataeng/fin-prj-01/data/www.kommersant.ru|RSS|news.xml/1672120673.json получили таблицу, кол-во строк 235.<=1367093449.py->feedfile_to_pandas[27]
# 2022-12-27 19:45:38,307:DEBUG.GET_RSS_DATA:DEBUG=>Таблица для файла:1672120673.json, строк:235, нач.:Tue, 27 Dec 2022 08:47:56 +0300 «Русагро» может уй, кон.:Sun, 25 Dec 2022 00:37:05 +0300 В США зимний шторм<=1933949487.py->join_all_feedfiles_pandas_sql[22]
# 2022-12-27 19:45:38,313:DEBUG.GET_RSS_DATA:DEBUG=>Прочитали содержимое файла /home/fedorov/mypy/dataeng/fin-prj-01/data/www.kommersant.ru|RSS|news.xml/1672082927.json. Кол-во записей: 270<=1367093449.py->feedfile_to_pandas[19]
# 2022-12-27 19:45:38,319:DEBUG.GET_RSS_DATA:DEBUG=>Из файла /home/fedorov/mypy/dataeng/fin-prj-01/data/www.kommersant.ru|RSS|news.xml/1672082927.json получили таблицу, кол-во строк 270.<=1367093449.py->feedfile_to_pandas[27]
# 2022-12-27 19:45:38,323:DEBUG.GET_RSS_DATA:DEBUG=>Таблица для файла:1672082927.json, строк:270, нач.:Mon, 26 Dec 2022 22:26:18 +0300 Правительство Росс, кон.:Sat, 24 Dec 2022 00:00:55 +0300 В Кемерово 13 чело<=1933949487.py->join_all_feedfiles_pandas_sql[22]
# 2022-12-27 19:45:38,329:DEBUG.GET_RSS_DATA:DEBUG=>Прочитали содержимое файла /home/fedorov/mypy/dataeng/fin-prj-01/data/www.kommersant.ru|RSS|news.xml/1672080991.json. Кол-во записей: 267<=1367093449.py->feedfile_to_pandas[19]
# 2022-12-27 19:45:38,335:DEBUG.GET_RSS_DATA:DEBUG=>Из файла /home/fedorov/mypy/dataeng/fin-prj-01/data/www.kommersant.ru|RSS|news.xml/1672080991.json получили таблицу, кол-во строк 267.<=1367093449.py->feedfile_to_pandas[27]
# 2022-12-27 19:45:38,339:DEBUG.GET_RSS_DATA:DEBUG=>Таблица для файла:1672080991.json, строк:267, нач.:Mon, 26 Dec 2022 21:50:10 +0300 Турция нашла место, кон.:Sat, 24 Dec 2022 00:00:55 +0300 В Кемерово 13 чело<=1933949487.py->join_all_feedfiles_pandas_sql[22]
# 2022-12-27 19:45:38,345:DEBUG.GET_RSS_DATA:DEBUG=>Прочитали содержимое файла /home/fedorov/mypy/dataeng/fin-prj-01/data/www.kommersant.ru|RSS|news.xml/1672080887.json. Кол-во записей: 267<=1367093449.py->feedfile_to_pandas[19]
# 2022-12-27 19:45:38,351:DEBUG.GET_RSS_DATA:DEBUG=>Из файла /home/fedorov/mypy/dataeng/fin-prj-01/data/www.kommersant.ru|RSS|news.xml/1672080887.json получили таблицу, кол-во строк 267.<=1367093449.py->feedfile_to_pandas[27]
# 2022-12-27 19:45:38,355:DEBUG.GET_RSS_DATA:DEBUG=>Таблица для файла:1672080887.json, строк:267, нач.:Mon, 26 Dec 2022 21:50:10 +0300 Турция нашла место, кон.:Sat, 24 Dec 2022 00:00:55 +0300 В Кемерово 13 чело<=1933949487.py->join_all_feedfiles_pandas_sql[22]
# 2022-12-27 19:45:38,361:DEBUG.GET_RSS_DATA:DEBUG=>Прочитали содержимое файла /home/fedorov/mypy/dataeng/fin-prj-01/data/www.kommersant.ru|RSS|news.xml/1672080852.json. Кол-во записей: 267<=1367093449.py->feedfile_to_pandas[19]
# 2022-12-27 19:45:38,367:DEBUG.GET_RSS_DATA:DEBUG=>Из файла /home/fedorov/mypy/dataeng/fin-prj-01/data/www.kommersant.ru|RSS|news.xml/1672080852.json получили таблицу, кол-во строк 267.<=1367093449.py->feedfile_to_pandas[27]
# 2022-12-27 19:45:38,371:DEBUG.GET_RSS_DATA:DEBUG=>Таблица для файла:1672080852.json, строк:267, нач.:Mon, 26 Dec 2022 21:50:10 +0300 Турция нашла место, кон.:Sat, 24 Dec 2022 00:00:55 +0300 В Кемерово 13 чело<=1933949487.py->join_all_feedfiles_pandas_sql[22]
# 2022-12-27 19:45:38,374:DEBUG.GET_RSS_DATA:DEBUG=>Сформировали сводную таблицу для файлов в /home/fedorov/mypy/dataeng/fin-prj-01/data/www.kommersant.ru|RSS|news.xml. Кол-во строк: 2842<=1933949487.py->join_all_feedfiles_pandas_sql[29]
# 2022-12-27 19:45:38,384:DEBUG.GET_RSS_DATA:DEBUG=>После удаления дубликатов: кол-во строк: 409<=1933949487.py->join_all_feedfiles_pandas_sql[31]
# 2022-12-27 19:45:38,532:DEBUG.GET_RSS_DATA:DEBUG=>Добавлено в БД в таблицу: www.kommersant.ru|RSS|news.xml<=1933949487.py->join_all_feedfiles_pandas_sql[35]
# 2022-12-27 19:45:38,534:DEBUG.GET_RSS_DATA:DEBUG=>Прочитали директорию /home/fedorov/mypy/dataeng/fin-prj-01/data/rossaprimavera.ru|rss. Кол-во файлов: 9. Список: ['1672159534.json', '1672159377.json', '1672148235.json', '1672126340.json', '1672120673.json', '1672082927.json', '1672080991.json', '1672080887.json', '1672080852.json']<=1933949487.py->join_all_feedfiles_pandas_sql[11]
# 2022-12-27 19:45:38,538:DEBUG.GET_RSS_DATA:DEBUG=>Прочитали содержимое файла /home/fedorov/mypy/dataeng/fin-prj-01/data/rossaprimavera.ru|rss/1672159534.json. Кол-во записей: 51<=1367093449.py->feedfile_to_pandas[19]
# 2022-12-27 19:45:38,542:DEBUG.GET_RSS_DATA:DEBUG=>Из файла /home/fedorov/mypy/dataeng/fin-prj-01/data/rossaprimavera.ru|rss/1672159534.json получили таблицу, кол-во строк 51.<=1367093449.py->feedfile_to_pandas[27]
# 2022-12-27 19:45:38,546:DEBUG.GET_RSS_DATA:DEBUG=>Таблица для файла:1672159534.json, строк:51, нач.:Tue, 27 Dec 2022 19:45:13 +0300 В МВД Косово заяви, кон.:Tue, 27 Dec 2022 18:13:20 +0300 На Ямале на фоне в<=1933949487.py->join_all_feedfiles_pandas_sql[22]
# 2022-12-27 19:45:38,547:DEBUG.GET_RSS_DATA:DEBUG=>Начальная инициализация пустой таблицы<=1933949487.py->join_all_feedfiles_pandas_sql[26]
# 2022-12-27 19:45:38,551:DEBUG.GET_RSS_DATA:DEBUG=>Прочитали содержимое файла /home/fedorov/mypy/dataeng/fin-prj-01/data/rossaprimavera.ru|rss/1672159377.json. Кол-во записей: 51<=1367093449.py->feedfile_to_pandas[19]
# 2022-12-27 19:45:38,555:DEBUG.GET_RSS_DATA:DEBUG=>Из файла /home/fedorov/mypy/dataeng/fin-prj-01/data/rossaprimavera.ru|rss/1672159377.json получили таблицу, кол-во строк 51.<=1367093449.py->feedfile_to_pandas[27]
# 2022-12-27 19:45:38,559:DEBUG.GET_RSS_DATA:DEBUG=>Таблица для файла:1672159377.json, строк:51, нач.:Tue, 27 Dec 2022 19:40:49 +0300 Бывший советник гл, кон.:Tue, 27 Dec 2022 18:11:41 +0300 В Косовска-Митрови<=1933949487.py->join_all_feedfiles_pandas_sql[22]
# 2022-12-27 19:45:38,562:DEBUG.GET_RSS_DATA:DEBUG=>Прочитали содержимое файла /home/fedorov/mypy/dataeng/fin-prj-01/data/rossaprimavera.ru|rss/1672148235.json. Кол-во записей: 51<=1367093449.py->feedfile_to_pandas[19]
# 2022-12-27 19:45:38,565:DEBUG.GET_RSS_DATA:DEBUG=>Из файла /home/fedorov/mypy/dataeng/fin-prj-01/data/rossaprimavera.ru|rss/1672148235.json получили таблицу, кол-во строк 51.<=1367093449.py->feedfile_to_pandas[27]
# 2022-12-27 19:45:38,568:DEBUG.GET_RSS_DATA:DEBUG=>Таблица для файла:1672148235.json, строк:51, нач.:Tue, 27 Dec 2022 16:36:00 +0300 Власти Испании зая, кон.:Tue, 27 Dec 2022 15:16:59 +0300 Около тысячи детей<=1933949487.py->join_all_feedfiles_pandas_sql[22]
# 2022-12-27 19:45:38,571:DEBUG.GET_RSS_DATA:DEBUG=>Прочитали содержимое файла /home/fedorov/mypy/dataeng/fin-prj-01/data/rossaprimavera.ru|rss/1672126340.json. Кол-во записей: 35<=1367093449.py->feedfile_to_pandas[19]
# 2022-12-27 19:45:38,573:DEBUG.GET_RSS_DATA:DEBUG=>Из файла /home/fedorov/mypy/dataeng/fin-prj-01/data/rossaprimavera.ru|rss/1672126340.json получили таблицу, кол-во строк 35.<=1367093449.py->feedfile_to_pandas[27]
# 2022-12-27 19:45:38,576:DEBUG.GET_RSS_DATA:DEBUG=>Таблица для файла:1672126340.json, строк:35, нач.:Tue, 27 Dec 2022 10:29:30 +0300 В Киеве на акции п, кон.: Tue, 27 Dec 2022 07:40:43 +0300 «Кливленд» проигр<=1933949487.py->join_all_feedfiles_pandas_sql[22]
# 2022-12-27 19:45:38,579:DEBUG.GET_RSS_DATA:DEBUG=>Прочитали содержимое файла /home/fedorov/mypy/dataeng/fin-prj-01/data/rossaprimavera.ru|rss/1672120673.json. Кол-во записей: 34<=1367093449.py->feedfile_to_pandas[19]
# 2022-12-27 19:45:38,583:DEBUG.GET_RSS_DATA:DEBUG=>Из файла /home/fedorov/mypy/dataeng/fin-prj-01/data/rossaprimavera.ru|rss/1672120673.json получили таблицу, кол-во строк 34.<=1367093449.py->feedfile_to_pandas[27]
# 2022-12-27 19:45:38,586:DEBUG.GET_RSS_DATA:DEBUG=>Таблица для файла:1672120673.json, строк:34, нач.:Tue, 27 Dec 2022 08:47:04 +0300 Чехи оценили предс, кон.:Tue, 27 Dec 2022 04:48:25 +0300 Китай обещает восс<=1933949487.py->join_all_feedfiles_pandas_sql[22]
# 2022-12-27 19:45:38,589:DEBUG.GET_RSS_DATA:DEBUG=>Прочитали содержимое файла /home/fedorov/mypy/dataeng/fin-prj-01/data/rossaprimavera.ru|rss/1672082927.json. Кол-во записей: 51<=1367093449.py->feedfile_to_pandas[19]
# 2022-12-27 19:45:38,592:DEBUG.GET_RSS_DATA:DEBUG=>Из файла /home/fedorov/mypy/dataeng/fin-prj-01/data/rossaprimavera.ru|rss/1672082927.json получили таблицу, кол-во строк 51.<=1367093449.py->feedfile_to_pandas[27]
# 2022-12-27 19:45:38,596:DEBUG.GET_RSS_DATA:DEBUG=>Таблица для файла:1672082927.json, строк:51, нач.:Mon, 26 Dec 2022 22:26:58 +0300 В Томске накануне , кон.:Mon, 26 Dec 2022 22:03:00 +0300 Участковый вынес п<=1933949487.py->join_all_feedfiles_pandas_sql[22]
# 2022-12-27 19:45:38,599:DEBUG.GET_RSS_DATA:DEBUG=>Прочитали содержимое файла /home/fedorov/mypy/dataeng/fin-prj-01/data/rossaprimavera.ru|rss/1672080991.json. Кол-во записей: 51<=1367093449.py->feedfile_to_pandas[19]
# 2022-12-27 19:45:38,603:DEBUG.GET_RSS_DATA:DEBUG=>Из файла /home/fedorov/mypy/dataeng/fin-prj-01/data/rossaprimavera.ru|rss/1672080991.json получили таблицу, кол-во строк 51.<=1367093449.py->feedfile_to_pandas[27]
# 2022-12-27 19:45:38,606:DEBUG.GET_RSS_DATA:DEBUG=>Таблица для файла:1672080991.json, строк:51, нач.:Mon, 26 Dec 2022 21:53:46 +0300 В Ливане арестован, кон.:Mon, 26 Dec 2022 21:24:41 +0300 В Сербии депутаты <=1933949487.py->join_all_feedfiles_pandas_sql[22]
# 2022-12-27 19:45:38,610:DEBUG.GET_RSS_DATA:DEBUG=>Прочитали содержимое файла /home/fedorov/mypy/dataeng/fin-prj-01/data/rossaprimavera.ru|rss/1672080887.json. Кол-во записей: 51<=1367093449.py->feedfile_to_pandas[19]
# ...
# 2022-12-27 19:45:39,214:DEBUG.GET_RSS_DATA:DEBUG=>Таблица для файла:1672080888.json, строк:200, нач.:Mon, 26 Dec 2022 18:17:00 +0300 «Россети» ищут оте, кон.:Thu, 15 Dec 2022 09:05:00 +0300 Операторы связи см<=1933949487.py->join_all_feedfiles_pandas_sql[22]
# 2022-12-27 19:45:39,219:DEBUG.GET_RSS_DATA:DEBUG=>Прочитали содержимое файла /home/fedorov/mypy/dataeng/fin-prj-01/data/www.cnews.ru|inc|rss|news.xml/1672080854.json. Кол-во записей: 200<=1367093449.py->feedfile_to_pandas[19]
# 2022-12-27 19:45:39,225:DEBUG.GET_RSS_DATA:DEBUG=>Из файла /home/fedorov/mypy/dataeng/fin-prj-01/data/www.cnews.ru|inc|rss|news.xml/1672080854.json получили таблицу, кол-во строк 200.<=1367093449.py->feedfile_to_pandas[27]
# 2022-12-27 19:45:39,228:DEBUG.GET_RSS_DATA:DEBUG=>Таблица для файла:1672080854.json, строк:200, нач.:Mon, 26 Dec 2022 18:17:00 +0300 «Россети» ищут оте, кон.:Thu, 15 Dec 2022 09:05:00 +0300 Операторы связи см<=1933949487.py->join_all_feedfiles_pandas_sql[22]
# 2022-12-27 19:45:39,230:DEBUG.GET_RSS_DATA:DEBUG=>Сформировали сводную таблицу для файлов в /home/fedorov/mypy/dataeng/fin-prj-01/data/www.cnews.ru|inc|rss|news.xml. Кол-во строк: 2000<=1933949487.py->join_all_feedfiles_pandas_sql[29]
# 2022-12-27 19:45:39,242:DEBUG.GET_RSS_DATA:DEBUG=>После удаления дубликатов: кол-во строк: 243<=1933949487.py->join_all_feedfiles_pandas_sql[31]
# 2022-12-27 19:45:39,447:DEBUG.GET_RSS_DATA:DEBUG=>Добавлено в БД в таблицу: www.cnews.ru|inc|rss|news.xml<=1933949487.py->join_all_feedfiles_pandas_sql[35]
# 2022-12-27 19:45:39,448:DEBUG.GET_RSS_DATA:DEBUG=>Прочитали директорию /home/fedorov/mypy/dataeng/fin-prj-01/data/hibinform.ru|feed|. Кол-во файлов: 9. Список: ['1672159536.json', '1672159378.json', '1672148237.json', '1672126341.json', '1672120675.json', '1672082929.json', '1672080993.json', '1672080889.json', '1672080854.json']<=1933949487.py->join_all_feedfiles_pandas_sql[11]
# 2022-12-27 19:45:39,451:DEBUG.GET_RSS_DATA:DEBUG=>Прочитали содержимое файла /home/fedorov/mypy/dataeng/fin-prj-01/data/hibinform.ru|feed|/1672159536.json. Кол-во записей: 10<=1367093449.py->feedfile_to_pandas[19]
# 2022-12-27 19:45:39,454:DEBUG.GET_RSS_DATA:DEBUG=>Из файла /home/fedorov/mypy/dataeng/fin-prj-01/data/hibinform.ru|feed|/1672159536.json получили таблицу, кол-во строк 10.<=1367093449.py->feedfile_to_pandas[27]
# 2022-12-27 19:45:39,458:DEBUG.GET_RSS_DATA:DEBUG=>Таблица для файла:1672159536.json, строк:10, нач.: Tue, 27 Dec 2022 12:40:42 +0000 Поднимать настрое, кон.: Wed, 21 Dec 2022 17:54:56 +0000 Апатитчане побыва<=1933949487.py->join_all_feedfiles_pandas_sql[22]
# 2022-12-27 19:45:39,459:DEBUG.GET_RSS_DATA:DEBUG=>Начальная инициализация пустой таблицы<=1933949487.py->join_all_feedfiles_pandas_sql[26]
# 2022-12-27 19:45:39,461:DEBUG.GET_RSS_DATA:DEBUG=>Прочитали содержимое файла /home/fedorov/mypy/dataeng/fin-prj-01/data/hibinform.ru|feed|/1672159378.json. Кол-во записей: 10<=1367093449.py->feedfile_to_pandas[19]
# 2022-12-27 19:45:39,465:DEBUG.GET_RSS_DATA:DEBUG=>Из файла /home/fedorov/mypy/dataeng/fin-prj-01/data/hibinform.ru|feed|/1672159378.json получили таблицу, кол-во строк 10.<=1367093449.py->feedfile_to_pandas[27]
# 2022-12-27 19:45:39,468:DEBUG.GET_RSS_DATA:DEBUG=>Таблица для файла:1672159378.json, строк:10, нач.: Tue, 27 Dec 2022 12:40:42 +0000 Поднимать настрое, кон.: Wed, 21 Dec 2022 17:54:56 +0000 Апатитчане побыва<=1933949487.py->join_all_feedfiles_pandas_sql[22]
# 2022-12-27 19:45:39,471:DEBUG.GET_RSS_DATA:DEBUG=>Прочитали содержимое файла /home/fedorov/mypy/dataeng/fin-prj-01/data/hibinform.ru|feed|/1672148237.json. Кол-во записей: 10<=1367093449.py->feedfile_to_pandas[19]
# 2022-12-27 19:45:39,474:DEBUG.GET_RSS_DATA:DEBUG=>Из файла /home/fedorov/mypy/dataeng/fin-prj-01/data/hibinform.ru|feed|/1672148237.json получили таблицу, кол-во строк 10.<=1367093449.py->feedfile_to_pandas[27]
# 2022-12-27 19:45:39,477:DEBUG.GET_RSS_DATA:DEBUG=>Таблица для файла:1672148237.json, строк:10, нач.: Tue, 27 Dec 2022 12:40:42 +0000 Поднимать настрое, кон.: Wed, 21 Dec 2022 17:54:56 +0000 Апатитчане побыва<=1933949487.py->join_all_feedfiles_pandas_sql[22]
# 2022-12-27 19:45:39,479:DEBUG.GET_RSS_DATA:DEBUG=>Прочитали содержимое файла /home/fedorov/mypy/dataeng/fin-prj-01/data/hibinform.ru|feed|/1672126341.json. Кол-во записей: 10<=1367093449.py->feedfile_to_pandas[19]
# 2022-12-27 19:45:39,483:DEBUG.GET_RSS_DATA:DEBUG=>Из файла /home/fedorov/mypy/dataeng/fin-prj-01/data/hibinform.ru|feed|/1672126341.json получили таблицу, кол-во строк 10.<=1367093449.py->feedfile_to_pandas[27]
# 2022-12-27 19:45:39,487:DEBUG.GET_RSS_DATA:DEBUG=>Таблица для файла:1672126341.json, строк:10, нач.:Sun, 25 Dec 2022 14:33:15 +0000 В Апатитах прошёл , кон.: Wed, 21 Dec 2022 09:57:09 +0000 В Апатитах старту<=1933949487.py->join_all_feedfiles_pandas_sql[22]
# 2022-12-27 19:45:39,490:DEBUG.GET_RSS_DATA:DEBUG=>Прочитали содержимое файла /home/fedorov/mypy/dataeng/fin-prj-01/data/hibinform.ru|feed|/1672120675.json. Кол-во записей: 10<=1367093449.py->feedfile_to_pandas[19]
# 2022-12-27 19:45:39,493:DEBUG.GET_RSS_DATA:DEBUG=>Из файла /home/fedorov/mypy/dataeng/fin-prj-01/data/hibinform.ru|feed|/1672120675.json получили таблицу, кол-во строк 10.<=1367093449.py->feedfile_to_pandas[27]
# 2022-12-27 19:45:39,497:DEBUG.GET_RSS_DATA:DEBUG=>Таблица для файла:1672120675.json, строк:10, нач.:Sun, 25 Dec 2022 14:33:15 +0000 В Апатитах прошёл , кон.: Wed, 21 Dec 2022 09:57:09 +0000 В Апатитах старту<=1933949487.py->join_all_feedfiles_pandas_sql[22]
# 2022-12-27 19:45:39,500:DEBUG.GET_RSS_DATA:DEBUG=>Прочитали содержимое файла /home/fedorov/mypy/dataeng/fin-prj-01/data/hibinform.ru|feed|/1672082929.json. Кол-во записей: 10<=1367093449.py->feedfile_to_pandas[19]
# 2022-12-27 19:45:39,503:DEBUG.GET_RSS_DATA:DEBUG=>Из файла /home/fedorov/mypy/dataeng/fin-prj-01/data/hibinform.ru|feed|/1672082929.json получили таблицу, кол-во строк 10.<=1367093449.py->feedfile_to_pandas[27]
# 2022-12-27 19:45:39,507:DEBUG.GET_RSS_DATA:DEBUG=>Таблица для файла:1672082929.json, строк:10, нач.:Sun, 25 Dec 2022 14:33:15 +0000 В Апатитах прошёл , кон.: Wed, 21 Dec 2022 09:57:09 +0000 В Апатитах старту<=1933949487.py->join_all_feedfiles_pandas_sql[22]
# 2022-12-27 19:45:39,510:DEBUG.GET_RSS_DATA:DEBUG=>Прочитали содержимое файла /home/fedorov/mypy/dataeng/fin-prj-01/data/hibinform.ru|feed|/1672080993.json. Кол-во записей: 10<=1367093449.py->feedfile_to_pandas[19]
# 2022-12-27 19:45:39,513:DEBUG.GET_RSS_DATA:DEBUG=>Из файла /home/fedorov/mypy/dataeng/fin-prj-01/data/hibinform.ru|feed|/1672080993.json получили таблицу, кол-во строк 10.<=1367093449.py->feedfile_to_pandas[27]
# 2022-12-27 19:45:39,517:DEBUG.GET_RSS_DATA:DEBUG=>Таблица для файла:1672080993.json, строк:10, нач.:Sun, 25 Dec 2022 14:33:15 +0000 В Апатитах прошёл , кон.: Wed, 21 Dec 2022 09:57:09 +0000 В Апатитах старту<=1933949487.py->join_all_feedfiles_pandas_sql[22]
# 2022-12-27 19:45:39,519:DEBUG.GET_RSS_DATA:DEBUG=>Прочитали содержимое файла /home/fedorov/mypy/dataeng/fin-prj-01/data/hibinform.ru|feed|/1672080889.json. Кол-во записей: 10<=1367093449.py->feedfile_to_pandas[19]
# 2022-12-27 19:45:39,523:DEBUG.GET_RSS_DATA:DEBUG=>Из файла /home/fedorov/mypy/dataeng/fin-prj-01/data/hibinform.ru|feed|/1672080889.json получили таблицу, кол-во строк 10.<=1367093449.py->feedfile_to_pandas[27]
# 2022-12-27 19:45:39,527:DEBUG.GET_RSS_DATA:DEBUG=>Таблица для файла:1672080889.json, строк:10, нач.:Sun, 25 Dec 2022 14:33:15 +0000 В Апатитах прошёл , кон.: Wed, 21 Dec 2022 09:57:09 +0000 В Апатитах старту<=1933949487.py->join_all_feedfiles_pandas_sql[22]
# 2022-12-27 19:45:39,528:DEBUG.GET_RSS_DATA:DEBUG=>Прочитали содержимое файла /home/fedorov/mypy/dataeng/fin-prj-01/data/hibinform.ru|feed|/1672080854.json. Кол-во записей: 10<=1367093449.py->feedfile_to_pandas[19]
# 2022-12-27 19:45:39,532:DEBUG.GET_RSS_DATA:DEBUG=>Из файла /home/fedorov/mypy/dataeng/fin-prj-01/data/hibinform.ru|feed|/1672080854.json получили таблицу, кол-во строк 10.<=1367093449.py->feedfile_to_pandas[27]
# 2022-12-27 19:45:39,536:DEBUG.GET_RSS_DATA:DEBUG=>Таблица для файла:1672080854.json, строк:10, нач.:Sun, 25 Dec 2022 14:33:15 +0000 В Апатитах прошёл , кон.: Wed, 21 Dec 2022 09:57:09 +0000 В Апатитах старту<=1933949487.py->join_all_feedfiles_pandas_sql[22]
# 2022-12-27 19:45:39,538:DEBUG.GET_RSS_DATA:DEBUG=>Сформировали сводную таблицу для файлов в /home/fedorov/mypy/dataeng/fin-prj-01/data/hibinform.ru|feed|. Кол-во строк: 100<=1933949487.py->join_all_feedfiles_pandas_sql[29]
# 2022-12-27 19:45:39,542:DEBUG.GET_RSS_DATA:DEBUG=>После удаления дубликатов: кол-во строк: 12<=1933949487.py->join_all_feedfiles_pandas_sql[31]
# 2022-12-27 19:45:39,681:DEBUG.GET_RSS_DATA:DEBUG=>Добавлено в БД в таблицу: hibinform.ru|feed|<=1933949487.py->join_all_feedfiles_pandas_sql[35]
# 2022-12-27 19:45:39,683:DEBUG.GET_RSS_DATA:DEBUG=>Прочитали директорию /home/fedorov/mypy/dataeng/fin-prj-01/data/habr.com|ru|rss|all|all|. Кол-во файлов: 9. Список: ['1672159536.json', '1672159379.json', '1672148238.json', '1672126342.json', '1672120675.json', '1672082930.json', '1672080993.json', '1672080889.json', '1672080855.json']<=1933949487.py->join_all_feedfiles_pandas_sql[11]
# 2022-12-27 19:45:39,685:DEBUG.GET_RSS_DATA:DEBUG=>Прочитали содержимое файла /home/fedorov/mypy/dataeng/fin-prj-01/data/habr.com|ru|rss|all|all|/1672159536.json. Кол-во записей: 20<=1367093449.py->feedfile_to_pandas[19]
# 2022-12-27 19:45:39,689:DEBUG.GET_RSS_DATA:DEBUG=>Из файла /home/fedorov/mypy/dataeng/fin-prj-01/data/habr.com|ru|rss|all|all|/1672159536.json получили таблицу, кол-во строк 20.<=1367093449.py->feedfile_to_pandas[27]
# 2022-12-27 19:45:39,693:DEBUG.GET_RSS_DATA:DEBUG=>Таблица для файла:1672159536.json, строк:20, нач.:Tue, 27 Dec 2022 16:30:49 GMT Новые батарейки Powe, кон.:Tue, 27 Dec 2022 12:17:28 GMT [Перевод] Изучение T<=1933949487.py->join_all_feedfiles_pandas_sql[22]
# 2022-12-27 19:45:39,694:DEBUG.GET_RSS_DATA:DEBUG=>Начальная инициализация пустой таблицы<=1933949487.py->join_all_feedfiles_pandas_sql[26]
# 2022-12-27 19:45:39,697:DEBUG.GET_RSS_DATA:DEBUG=>Прочитали содержимое файла /home/fedorov/mypy/dataeng/fin-prj-01/data/habr.com|ru|rss|all|all|/1672159379.json. Кол-во записей: 20<=1367093449.py->feedfile_to_pandas[19]
# 2022-12-27 19:45:39,700:DEBUG.GET_RSS_DATA:DEBUG=>Из файла /home/fedorov/mypy/dataeng/fin-prj-01/data/habr.com|ru|rss|all|all|/1672159379.json получили таблицу, кол-во строк 20.<=1367093449.py->feedfile_to_pandas[27]
# 2022-12-27 19:45:39,704:DEBUG.GET_RSS_DATA:DEBUG=>Таблица для файла:1672159379.json, строк:20, нач.:Tue, 27 Dec 2022 16:30:49 GMT Новые батарейки Powe, кон.:Tue, 27 Dec 2022 12:17:28 GMT [Перевод] Изучение T<=1933949487.py->join_all_feedfiles_pandas_sql[22]
# 2022-12-27 19:45:39,706:DEBUG.GET_RSS_DATA:DEBUG=>Прочитали содержимое файла /home/fedorov/mypy/dataeng/fin-prj-01/data/habr.com|ru|rss|all|all|/1672148238.json. Кол-во записей: 20<=1367093449.py->feedfile_to_pandas[19]
# 2022-12-27 19:45:39,710:DEBUG.GET_RSS_DATA:DEBUG=>Из файла /home/fedorov/mypy/dataeng/fin-prj-01/data/habr.com|ru|rss|all|all|/1672148238.json получили таблицу, кол-во строк 20.<=1367093449.py->feedfile_to_pandas[27]
# 2022-12-27 19:45:39,714:DEBUG.GET_RSS_DATA:DEBUG=>Таблица для файла:1672148238.json, строк:20, нач.:Tue, 27 Dec 2022 13:08:15 GMT [Перевод] Рельсовая , кон.: Tue, 27 Dec 2022 11:09:10 GMT Как выбрать NewSQL-<=1933949487.py->join_all_feedfiles_pandas_sql[22]
# 2022-12-27 19:45:39,716:DEBUG.GET_RSS_DATA:DEBUG=>Прочитали содержимое файла /home/fedorov/mypy/dataeng/fin-prj-01/data/habr.com|ru|rss|all|all|/1672126342.json. Кол-во записей: 20<=1367093449.py->feedfile_to_pandas[19]
# 2022-12-27 19:45:39,720:DEBUG.GET_RSS_DATA:DEBUG=>Из файла /home/fedorov/mypy/dataeng/fin-prj-01/data/habr.com|ru|rss|all|all|/1672126342.json получили таблицу, кол-во строк 20.<=1367093449.py->feedfile_to_pandas[27]
# 2022-12-27 19:45:39,724:DEBUG.GET_RSS_DATA:DEBUG=>Таблица для файла:1672126342.json, строк:20, нач.:Tue, 27 Dec 2022 07:27:37 GMT Приемы для ускорения, кон.:Mon, 26 Dec 2022 20:11:16 GMT Крипта на пальцах, н<=1933949487.py->join_all_feedfiles_pandas_sql[22]
# 2022-12-27 19:45:39,726:DEBUG.GET_RSS_DATA:DEBUG=>Прочитали содержимое файла /home/fedorov/mypy/dataeng/fin-prj-01/data/habr.com|ru|rss|all|all|/1672120675.json. Кол-во записей: 20<=1367093449.py->feedfile_to_pandas[19]
# 2022-12-27 19:45:39,729:DEBUG.GET_RSS_DATA:DEBUG=>Из файла /home/fedorov/mypy/dataeng/fin-prj-01/data/habr.com|ru|rss|all|all|/1672120675.json получили таблицу, кол-во строк 20.<=1367093449.py->feedfile_to_pandas[27]
# 2022-12-27 19:45:39,733:DEBUG.GET_RSS_DATA:DEBUG=>Таблица для файла:1672120675.json, строк:20, нач.:Tue, 27 Dec 2022 05:34:57 GMT Российские активы в , кон.:Mon, 26 Dec 2022 13:50:16 GMT Карьера Linux-инжене<=1933949487.py->join_all_feedfiles_pandas_sql[22]
# 2022-12-27 19:45:39,736:DEBUG.GET_RSS_DATA:DEBUG=>Прочитали содержимое файла /home/fedorov/mypy/dataeng/fin-prj-01/data/habr.com|ru|rss|all|all|/1672082930.json. Кол-во записей: 20<=1367093449.py->feedfile_to_pandas[19]
# 2022-12-27 19:45:39,739:DEBUG.GET_RSS_DATA:DEBUG=>Из файла /home/fedorov/mypy/dataeng/fin-prj-01/data/habr.com|ru|rss|all|all|/1672082930.json получили таблицу, кол-во строк 20.<=1367093449.py->feedfile_to_pandas[27]
# 2022-12-27 19:45:39,743:DEBUG.GET_RSS_DATA:DEBUG=>Таблица для файла:1672082930.json, строк:20, нач.:Mon, 26 Dec 2022 17:47:16 GMT Прикладной MEV или к, кон.: Mon, 26 Dec 2022 12:06:50 GMT Стоимость открытия <=1933949487.py->join_all_feedfiles_pandas_sql[22]
# 2022-12-27 19:45:39,746:DEBUG.GET_RSS_DATA:DEBUG=>Прочитали содержимое файла /home/fedorov/mypy/dataeng/fin-prj-01/data/habr.com|ru|rss|all|all|/1672080993.json. Кол-во записей: 20<=1367093449.py->feedfile_to_pandas[19]
# 2022-12-27 19:45:39,749:DEBUG.GET_RSS_DATA:DEBUG=>Из файла /home/fedorov/mypy/dataeng/fin-prj-01/data/habr.com|ru|rss|all|all|/1672080993.json получили таблицу, кол-во строк 20.<=1367093449.py->feedfile_to_pandas[27]
# 2022-12-27 19:45:39,753:DEBUG.GET_RSS_DATA:DEBUG=>Таблица для файла:1672080993.json, строк:20, нач.:Mon, 26 Dec 2022 17:47:16 GMT Прикладной MEV или к, кон.: Mon, 26 Dec 2022 12:06:50 GMT Стоимость открытия <=1933949487.py->join_all_feedfiles_pandas_sql[22]
# 2022-12-27 19:45:39,755:DEBUG.GET_RSS_DATA:DEBUG=>Прочитали содержимое файла /home/fedorov/mypy/dataeng/fin-prj-01/data/habr.com|ru|rss|all|all|/1672080889.json. Кол-во записей: 20<=1367093449.py->feedfile_to_pandas[19]
# 2022-12-27 19:45:39,759:DEBUG.GET_RSS_DATA:DEBUG=>Из файла /home/fedorov/mypy/dataeng/fin-prj-01/data/habr.com|ru|rss|all|all|/1672080889.json получили таблицу, кол-во строк 20.<=1367093449.py->feedfile_to_pandas[27]
# 2022-12-27 19:45:39,763:DEBUG.GET_RSS_DATA:DEBUG=>Таблица для файла:1672080889.json, строк:20, нач.:Mon, 26 Dec 2022 17:47:16 GMT Прикладной MEV или к, кон.: Mon, 26 Dec 2022 12:06:50 GMT Стоимость открытия <=1933949487.py->join_all_feedfiles_pandas_sql[22]
# 2022-12-27 19:45:39,766:DEBUG.GET_RSS_DATA:DEBUG=>Прочитали содержимое файла /home/fedorov/mypy/dataeng/fin-prj-01/data/habr.com|ru|rss|all|all|/1672080855.json. Кол-во записей: 20<=1367093449.py->feedfile_to_pandas[19]
# 2022-12-27 19:45:39,769:DEBUG.GET_RSS_DATA:DEBUG=>Из файла /home/fedorov/mypy/dataeng/fin-prj-01/data/habr.com|ru|rss|all|all|/1672080855.json получили таблицу, кол-во строк 20.<=1367093449.py->feedfile_to_pandas[27]
# 2022-12-27 19:45:39,773:DEBUG.GET_RSS_DATA:DEBUG=>Таблица для файла:1672080855.json, строк:20, нач.:Mon, 26 Dec 2022 17:47:16 GMT Прикладной MEV или к, кон.: Mon, 26 Dec 2022 12:06:50 GMT Стоимость открытия <=1933949487.py->join_all_feedfiles_pandas_sql[22]
# 2022-12-27 19:45:39,774:DEBUG.GET_RSS_DATA:DEBUG=>Сформировали сводную таблицу для файлов в /home/fedorov/mypy/dataeng/fin-prj-01/data/habr.com|ru|rss|all|all|. Кол-во строк: 200<=1933949487.py->join_all_feedfiles_pandas_sql[29]
# 2022-12-27 19:45:39,780:DEBUG.GET_RSS_DATA:DEBUG=>После удаления дубликатов: кол-во строк: 76<=1933949487.py->join_all_feedfiles_pandas_sql[31]
# 2022-12-27 19:45:39,896:DEBUG.GET_RSS_DATA:DEBUG=>Добавлено в БД в таблицу: habr.com|ru|rss|all|all|<=1933949487.py->join_all_feedfiles_pandas_sql[35]

# %%
df_rez
# Out:
#                                                  title  \
# 0    В Макеевке задержаны подозреваемые в убийстве ...
# 1    В Хабаровском крае зарегистрировали два леталь...
# 2    Глава Каталонии надеется на прогресс в вопросе...
# 3    Два человека погибли в результате ДТП в Липецк...
# 4    FT: республиканцы в Конгрессе не могут договор...
# ..                                                 ...
# 208       Глава правительства Мордовии ушел в отставку
# 209          Зимняя буря в США унесла жизни 50 человек
# 210  Киевские нацисты обстреляли Донецк, Гольмовски...
# 211  Дело о дискредитации ВС возбуждено против дире...
# 212  Путин поздравил народы и лидеров стран СНГ с н...
#
#                                     link                   publish_date  \
# 0    https://regnum.ru/news/3765068.html  Tue, 27 Dec 2022 07:26:00 GMT
# 1    https://regnum.ru/news/3765070.html  Tue, 27 Dec 2022 07:27:00 GMT
# 2    https://regnum.ru/news/3765067.html  Tue, 27 Dec 2022 07:25:00 GMT
# 3    https://regnum.ru/news/3765069.html  Tue, 27 Dec 2022 07:26:00 GMT
# 4    https://regnum.ru/news/3765065.html  Tue, 27 Dec 2022 07:15:00 GMT
# ..                                   ...                            ...
# 208  https://regnum.ru/news/3764910.html  Mon, 26 Dec 2022 14:18:00 GMT
# 209  https://regnum.ru/news/3764906.html  Mon, 26 Dec 2022 14:13:00 GMT
# 210  https://regnum.ru/news/3764900.html  Mon, 26 Dec 2022 14:05:00 GMT
# 211  https://regnum.ru/news/3764880.html  Mon, 26 Dec 2022 13:18:00 GMT
# 212  https://regnum.ru/news/3764877.html  Mon, 26 Dec 2022 13:09:00 GMT
#
#          category                                        description  \
# 0        Общество  \nПравоохранительные органы задержали подозрев...
# 1        В России  \nНа территории Хабаровского края медиками зар...
# 2        Политика  \nГлава правительства Каталонии Пере Арагонес ...
# 3    Происшествия  \nВ результате дорожно-транспортного происшест...
# 4        Политика  \nВ вопросе о продолжении предоставления помощ...
# ..            ...                                                ...
# 208      Политика  \nПредседатель правительства республики Мордов...
# 209  Происшествия  \nК утру понедельник как минимум 50 человек по...
# 210      Политика  \nВооружённые формирования киевского режима об...
# 211      Общество  \nВ отношении директора музея истории Екатерин...
# 212      В России  \nПрезидент России Владимир Путин поздравил ли...
#
#             source
# 0    regnum.ru|rss
# 1    regnum.ru|rss
# 2    regnum.ru|rss
# 3    regnum.ru|rss
# 4    regnum.ru|rss
# ..             ...
# 208  regnum.ru|rss
# 209  regnum.ru|rss
# 210  regnum.ru|rss
# 211  regnum.ru|rss
# 212  regnum.ru|rss
#
# [213 rows x 6 columns]

# %% [markdown]
# ## 2. ? Взять самый свежий файл и следующий за ним файл и объединить, убрав повторения

# %%
# def join_two_feeds(rss_url:str, rss_file_name1:str, rss_file_name2:str):
#     """ Сливает два фида, представленных таблицами пандас, в один , удаляя повторения
#     """
    
#     df1 = feedfile_to_pandas(rss_url, rss_file_name1)
#     df2 = feedfile_to_pandas(rss_url, rss_file_name2)
#     df_rez = pd.concat([df1, df2] )#,ignore_index=True
#     df_rez.drop_duplicates(inplace=True)
    
#     return df_rez

# %%
# подготавливаем папки для хранения скачиваемых из РСС данных
rss_url = 'https://regnum.ru/rss'# 'https://ria.ru/export/rss2/archive/index.xml' #'https://lenta.ru/rss/' # rss_urls[0]
rss_dirname = rssname_to_dirname(rss_url) #rss_url.replace(u'https://', "").replace(u"/","|") # rss_dir_prepare(rss_url)
abs_rss_dirname = os.path.join(DATA_DIR_NAME, rss_dirname)

# получаем список сохраненных файлов
list_dir = [ fn for fn in sorted( os.listdir(abs_rss_dirname), reverse=True) if '.json' in fn]
logger.debug(f'Прочитали директорию {abs_rss_dirname}. Файлов: {len(list_dir)}. Список: {list_dir}')

#самый свежий файл
file0 = list_dir[0]
df0 = feedfile_to_pandas(rss_url, file0)
# открываем следующий файл - это файл чуть старее,чем первый
file1 = list_dir[1]
df1 = feedfile_to_pandas(rss_url, file1)
# Out:
# 2022-12-27 19:47:41,171:DEBUG.GET_RSS_DATA:DEBUG=>Прочитали директорию /home/fedorov/mypy/dataeng/fin-prj-01/data/regnum.ru|rss. Файлов: 9. Список: ['1672159535.json', '1672159377.json', '1672148236.json', '1672126340.json', '1672120674.json', '1672082928.json', '1672080992.json', '1672080888.json', '1672080854.json']<=978801991.py-><module>[8]
# 2022-12-27 19:47:41,176:DEBUG.GET_RSS_DATA:DEBUG=>Прочитали содержимое файла /home/fedorov/mypy/dataeng/fin-prj-01/data/regnum.ru|rss/1672159535.json. Кол-во записей: 100<=1367093449.py->feedfile_to_pandas[19]
# 2022-12-27 19:47:41,182:DEBUG.GET_RSS_DATA:DEBUG=>Из файла /home/fedorov/mypy/dataeng/fin-prj-01/data/regnum.ru|rss/1672159535.json получили таблицу, кол-во строк 100.<=1367093449.py->feedfile_to_pandas[27]
# 2022-12-27 19:47:41,188:DEBUG.GET_RSS_DATA:DEBUG=>Прочитали содержимое файла /home/fedorov/mypy/dataeng/fin-prj-01/data/regnum.ru|rss/1672159377.json. Кол-во записей: 100<=1367093449.py->feedfile_to_pandas[19]
# 2022-12-27 19:47:41,192:DEBUG.GET_RSS_DATA:DEBUG=>Из файла /home/fedorov/mypy/dataeng/fin-prj-01/data/regnum.ru|rss/1672159377.json получили таблицу, кол-во строк 100.<=1367093449.py->feedfile_to_pandas[27]

# %%
df0.iloc[0:5,:]
# Out:
#                                                title  \
# 0  Суд обязал Рауля Арашукова выплатить Газпрому ...
# 1  ВСУ в пятый раз за сутки обстреляли Ясиноватую...
# 2  Зеленский ждет от Италии поставок систем проти...
# 3  Поезда на Рижском направлении в Москве задержи...
# 4                Пробки в столице достигли 10 баллов
#
#                                   link                   publish_date  \
# 0  https://regnum.ru/news/3765289.html  Tue, 27 Dec 2022 16:44:51 GMT
# 1  https://regnum.ru/news/3765288.html  Tue, 27 Dec 2022 16:44:39 GMT
# 2  https://regnum.ru/news/3765284.html  Tue, 27 Dec 2022 16:31:00 GMT
# 3  https://regnum.ru/news/3765286.html  Tue, 27 Dec 2022 16:37:00 GMT
# 4  https://regnum.ru/news/3765285.html  Tue, 27 Dec 2022 16:33:00 GMT
#
#        category                                        description  \
# 0      Общество  \nРауль Арашуков, которого суд приговорил к по...
# 1      В России  \nБоевики киевского режима обстреляли Ясиноват...
# 2        В мире  \nГлава киевского режима Владимир Зеленский в ...
# 3  Происшествия  \nВ расписании поездов на Рижском направления ...
# 4      В России  \nПробки в Москве вечером 27 декабря достигли ...
#
#           source
# 0  regnum.ru|rss
# 1  regnum.ru|rss
# 2  regnum.ru|rss
# 3  regnum.ru|rss
# 4  regnum.ru|rss

# %%
df1.iloc[0:5,:]
# Out:
#                                                title  \
# 0  Зеленский ждет от Италии поставок систем проти...
# 1  Поезда на Рижском направлении в Москве задержи...
# 2                Пробки в столице достигли 10 баллов
# 3  В Австрии предупредили о риске деиндустриализа...
# 4  МИД Болгарии вызвал посла России из-за объявле...
#
#                                   link                   publish_date  \
# 0  https://regnum.ru/news/3765284.html  Tue, 27 Dec 2022 16:31:00 GMT
# 1  https://regnum.ru/news/3765286.html  Tue, 27 Dec 2022 16:37:00 GMT
# 2  https://regnum.ru/news/3765285.html  Tue, 27 Dec 2022 16:33:00 GMT
# 3  https://regnum.ru/news/3765283.html  Tue, 27 Dec 2022 16:30:00 GMT
# 4  https://regnum.ru/news/3765280.html  Tue, 27 Dec 2022 16:31:53 GMT
#
#        category                                        description  \
# 0        В мире  \nГлава киевского режима Владимир Зеленский в ...
# 1  Происшествия  \nВ расписании поездов на Рижском направления ...
# 2      В России  \nПробки в Москве вечером 27 декабря достигли ...
# 3        В мире  \nЕвропе может грозить деиндустриализация. Так...
# 4      Политика  \nМинистерство иностранных дел Болгарии 27 дек...
#
#           source
# 0  regnum.ru|rss
# 1  regnum.ru|rss
# 2  regnum.ru|rss
# 3  regnum.ru|rss
# 4  regnum.ru|rss

# %%
dfx = df0.merge(df1, on=['title', 'link', 'publish_date', 'category', 'description', 'source' ], how='right', indicator= True ).dropna()
dfx[dfx._merge == 'right_only' ]
# Out:
#                                                 title  \
# 0   GT: РФ показывает силу для долгосрочного проти...
# 1   Апелляционный суд увеличил штраф экс-гендирект...
# 2   Лавров назвал целью НАТО уничтожение России «н...
# 21  Женщина-офицер помогла уничтожить танки и брон...
# 28  Супруга вернувшегося из американской тюрьмы Бу...
# 30  Экс-премьер Италии Берлускони заявил о «слабой...
# 32  Чиновника, обвиняемого в получении взяток при ...
# 73       Глава правительства Мордовии ушел в отставку
# 74  AFP: во Франции двое главных обвиняемых по дел...
# 75  FIFA не станет отстранять Россию от участия на...
# 76  В Астрахани обвиняемый в стрельбе из пневматик...
# 77   В Эритрее произошло землетрясение магнитудой 5,5
# 78  Восемь человек погибли, 19 пропали без вести в...
# 79  Стало известно о значительном ухудшении состоя...
# 80  В Воронежской области зафиксирован редкий для ...
# 81  В Кабардино-Балкарии предлагают земельные учас...
# 82  Более 100 тыс. домов в Канаде четвёртый день о...
# 83  На Эльбрусе восстановят самую старую высокогор...
# 84  В Нигере при падении военного вертолета погибл...
# 85  Коммунисты Молдавии обвинили Санду в создании ...
# 86  Глава Минобороны России поблагодарил Обществен...
# 87  Белоруссия открыла на границе с Украиной погра...
# 88  Нацбюро экспертизы Грузии опровергло заявление...
# 89  Песков направил журналистам поздравительную от...
# 90  Цены на нефтепродукты в Германии за год достиг...
# 91  Express: Шотландия может попасть в сферу влиян...
# 92  В парламенте Грузии не осталось голодающих деп...
# 93  Новейший британский авианосец чаще находится н...
# 94  Замначальника управления по цифровизации Росав...
# 95  Украина с 1 января повысит тариф на прокачку р...
# 96  МИД Грузии отреагировал на обвинение в непредо...
# 97  В результате снежной бури в США погибли 55 чел...
# 98  В Росавиации опровергли сообщения об обысках у...
# 99  Саакашвили выдвинул условие для проведения у н...
#
#                                    link                   publish_date  \
# 0   https://regnum.ru/news/3765043.html  Tue, 27 Dec 2022 05:48:00 GMT
# 1   https://regnum.ru/news/3765044.html  Tue, 27 Dec 2022 05:50:02 GMT
# 2   https://regnum.ru/news/3765042.html  Tue, 27 Dec 2022 05:46:00 GMT
# 21  https://regnum.ru/news/3765026.html  Tue, 27 Dec 2022 04:01:00 GMT
# 28  https://regnum.ru/news/3765027.html  Tue, 27 Dec 2022 03:55:50 GMT
# 30  https://regnum.ru/news/3765025.html  Tue, 27 Dec 2022 03:31:33 GMT
# 32  https://regnum.ru/news/3765019.html  Tue, 27 Dec 2022 03:13:43 GMT
# 73  https://regnum.ru/news/3764910.html  Mon, 26 Dec 2022 14:18:00 GMT
# 74  https://regnum.ru/news/3764916.html  Mon, 26 Dec 2022 14:35:00 GMT
# 75  https://regnum.ru/news/3764919.html  Mon, 26 Dec 2022 14:46:00 GMT
# 76  https://regnum.ru/news/3764920.html  Mon, 26 Dec 2022 14:51:00 GMT
# 77  https://regnum.ru/news/3764924.html  Mon, 26 Dec 2022 15:04:00 GMT
# 78  https://regnum.ru/news/3764928.html  Mon, 26 Dec 2022 15:11:00 GMT
# 79  https://regnum.ru/news/3764969.html  Mon, 26 Dec 2022 18:37:00 GMT
# 80  https://regnum.ru/news/3764970.html  Mon, 26 Dec 2022 18:43:00 GMT
# 81  https://regnum.ru/news/3764971.html  Mon, 26 Dec 2022 18:50:00 GMT
# 82  https://regnum.ru/news/3764967.html  Mon, 26 Dec 2022 18:31:41 GMT
# 83  https://regnum.ru/news/3764968.html  Mon, 26 Dec 2022 18:24:00 GMT
# 84  https://regnum.ru/news/3764937.html  Mon, 26 Dec 2022 15:37:00 GMT
# 85  https://regnum.ru/news/3764965.html  Mon, 26 Dec 2022 18:16:00 GMT
# 86  https://regnum.ru/news/3764942.html  Mon, 26 Dec 2022 16:00:00 GMT
# 87  https://regnum.ru/news/3764946.html  Mon, 26 Dec 2022 16:13:00 GMT
# 88  https://regnum.ru/news/3764947.html  Mon, 26 Dec 2022 16:16:00 GMT
# 89  https://regnum.ru/news/3764930.html  Mon, 26 Dec 2022 15:20:00 GMT
# 90  https://regnum.ru/news/3764952.html  Mon, 26 Dec 2022 16:37:00 GMT
# 91  https://regnum.ru/news/3764954.html  Mon, 26 Dec 2022 16:49:00 GMT
# 92  https://regnum.ru/news/3764955.html  Mon, 26 Dec 2022 16:53:00 GMT
# 93  https://regnum.ru/news/3764957.html  Mon, 26 Dec 2022 16:55:00 GMT
# 94  https://regnum.ru/news/3764962.html  Mon, 26 Dec 2022 17:24:00 GMT
# 95  https://regnum.ru/news/3764964.html  Mon, 26 Dec 2022 17:41:00 GMT
# 96  https://regnum.ru/news/3764961.html  Mon, 26 Dec 2022 17:46:00 GMT
# 97  https://regnum.ru/news/3764966.html  Mon, 26 Dec 2022 18:00:00 GMT
# 98  https://regnum.ru/news/3764931.html  Mon, 26 Dec 2022 15:22:00 GMT
# 99  https://regnum.ru/news/3764963.html  Mon, 26 Dec 2022 17:48:00 GMT
#
#         category                                        description  \
# 0       Политика  \nСилу для долгосрочного противостояния киевск...
# 1   Происшествия  \nРешение об увеличении размера штрафа экс-сов...
# 2       Политика  \nПобеду над Россией на поле боя назвал целью ...
# 21      В России  \nБлагодаря профессиональным действиям гвардии...
# 28      В России  \nРезультаты медицинского обследования Виктора...
# 30      Политика  \nЗапуск переговоров о мире на Украине считает...
# 32        В мире  \nБывший член организационного комитета Токийс...
# 73      Политика  \nПредседатель правительства Республики Мордов...
# 74  Происшествия  \nДвое мужчин, приговоренных к 18 годам лишени...
# 75         Спорт  \nМеждународная федерация футбола (FIFA) не ст...
# 76  Происшествия  \nЖитель Астрахани получил 3,5 года колонии за...
# 77  Происшествия  \nГеологическая служба США 26 декабря зарегист...
# 78  Происшествия  \nНаводнения, вызванные проливными дождями в ю...
# 79         Спорт  \nБразильский футболист, трёхкратный чемпион м...
# 80      Общество  \nВ Воронежской области повысился уровень воды...
# 81     Экономика  \nВ особой экономической зоне на территории вс...
# 82  Происшествия  \nПорядка 102 тыс. жилых домов и других сооруж...
# 83      Общество  \nНа Эльбрусе планируют восстановить одну из с...
# 84  Происшествия  \nВ столице Нигера три человека погибли при па...
# 85      Политика  \nПрезидент Молдавии Майя Санду и её партия «Д...
# 86      Общество  \nМинистр обороны России генерал армии Сергей ...
# 87        В мире  \nБелоруссия открыла новую пограничную заставу...
# 88      Политика  \nЗаявление, что у Национального бюро эксперти...
# 89      Политика  \nПресс-секретарь президента России Дмитрий Пе...
# 90     Экономика  \nЦены на дизель и бензин в Германии за уходящ...
# 91      Политика  \nВыход Шотландии из состава Соединённого Коро...
# 92      Политика  \nВ парламенте Грузии не осталось депутатов, к...
# 93        В мире  \nНовейший британский авианосец HMS Prince of ...
# 94      Общество  \nПодозреваемый во взятке сотрудник Росавиации...
# 95     Экономика  \nУкраина поднимет цену на прокачку российской...
# 96      Политика  \nМинистерство иностранных дел Грузии опроверг...
# 97  Происшествия  \nСнежная буря, разыгравшаяся в 12 штатах США,...
# 98      Общество  \nСотрудник управления цифровой трансформации ...
# 99      Политика  \nБывший президент Грузии Михаил Саакашвили со...
#
#            source      _merge
# 0   regnum.ru|rss  right_only
# 1   regnum.ru|rss  right_only
# 2   regnum.ru|rss  right_only
# 21  regnum.ru|rss  right_only
# 28  regnum.ru|rss  right_only
# 30  regnum.ru|rss  right_only
# 32  regnum.ru|rss  right_only
# 73  regnum.ru|rss  right_only
# 74  regnum.ru|rss  right_only
# 75  regnum.ru|rss  right_only
# 76  regnum.ru|rss  right_only
# 77  regnum.ru|rss  right_only
# 78  regnum.ru|rss  right_only
# 79  regnum.ru|rss  right_only
# 80  regnum.ru|rss  right_only
# 81  regnum.ru|rss  right_only
# 82  regnum.ru|rss  right_only
# 83  regnum.ru|rss  right_only
# 84  regnum.ru|rss  right_only
# 85  regnum.ru|rss  right_only
# 86  regnum.ru|rss  right_only
# 87  regnum.ru|rss  right_only
# 88  regnum.ru|rss  right_only
# 89  regnum.ru|rss  right_only
# 90  regnum.ru|rss  right_only
# 91  regnum.ru|rss  right_only
# 92  regnum.ru|rss  right_only
# 93  regnum.ru|rss  right_only
# 94  regnum.ru|rss  right_only
# 95  regnum.ru|rss  right_only
# 96  regnum.ru|rss  right_only
# 97  regnum.ru|rss  right_only
# 98  regnum.ru|rss  right_only
# 99  regnum.ru|rss  right_only

# %%
df_rez = pd.concat([df0, df1] )#,ignore_index=True
df_rez
# Out:
#                                                 title  \
# 0   В Макеевке задержаны подозреваемые в убийстве ...
# 1   В Хабаровском крае зарегистрировали два леталь...
# 2   Глава Каталонии надеется на прогресс в вопросе...
# 3   Два человека погибли в результате ДТП в Липецк...
# 4   FT: республиканцы в Конгрессе не могут договор...
# ..                                                ...
# 95  Украина с 1 января повысит тариф на прокачку р...
# 96  МИД Грузии отреагировал на обвинение в непредо...
# 97  В результате снежной бури в США погибли 55 чел...
# 98  В Росавиации опровергли сообщения об обысках у...
# 99  Саакашвили выдвинул условие для проведения у н...
#
#                                    link                   publish_date  \
# 0   https://regnum.ru/news/3765068.html  Tue, 27 Dec 2022 07:26:00 GMT
# 1   https://regnum.ru/news/3765070.html  Tue, 27 Dec 2022 07:27:00 GMT
# 2   https://regnum.ru/news/3765067.html  Tue, 27 Dec 2022 07:25:00 GMT
# 3   https://regnum.ru/news/3765069.html  Tue, 27 Dec 2022 07:26:00 GMT
# 4   https://regnum.ru/news/3765065.html  Tue, 27 Dec 2022 07:15:00 GMT
# ..                                  ...                            ...
# 95  https://regnum.ru/news/3764964.html  Mon, 26 Dec 2022 17:41:00 GMT
# 96  https://regnum.ru/news/3764961.html  Mon, 26 Dec 2022 17:46:00 GMT
# 97  https://regnum.ru/news/3764966.html  Mon, 26 Dec 2022 18:00:00 GMT
# 98  https://regnum.ru/news/3764931.html  Mon, 26 Dec 2022 15:22:00 GMT
# 99  https://regnum.ru/news/3764963.html  Mon, 26 Dec 2022 17:48:00 GMT
#
#         category                                        description  \
# 0       Общество  \nПравоохранительные органы задержали подозрев...
# 1       В России  \nНа территории Хабаровского края медиками зар...
# 2       Политика  \nГлава правительства Каталонии Пере Арагонес ...
# 3   Происшествия  \nВ результате дорожно-транспортного происшест...
# 4       Политика  \nВ вопросе о продолжении предоставления помощ...
# ..           ...                                                ...
# 95     Экономика  \nУкраина поднимет цену на прокачку российской...
# 96      Политика  \nМинистерство иностранных дел Грузии опроверг...
# 97  Происшествия  \nСнежная буря, разыгравшаяся в 12 штатах США,...
# 98      Общество  \nСотрудник управления цифровой трансформации ...
# 99      Политика  \nБывший президент Грузии Михаил Саакашвили со...
#
#            source
# 0   regnum.ru|rss
# 1   regnum.ru|rss
# 2   regnum.ru|rss
# 3   regnum.ru|rss
# 4   regnum.ru|rss
# ..            ...
# 95  regnum.ru|rss
# 96  regnum.ru|rss
# 97  regnum.ru|rss
# 98  regnum.ru|rss
# 99  regnum.ru|rss
#
# [200 rows x 6 columns]

# %%
df_rez.drop_duplicates()
# Out:
#                                                 title  \
# 0   В Макеевке задержаны подозреваемые в убийстве ...
# 1   В Хабаровском крае зарегистрировали два леталь...
# 2   Глава Каталонии надеется на прогресс в вопросе...
# 3   Два человека погибли в результате ДТП в Липецк...
# 4   FT: республиканцы в Конгрессе не могут договор...
# ..                                                ...
# 95  Украина с 1 января повысит тариф на прокачку р...
# 96  МИД Грузии отреагировал на обвинение в непредо...
# 97  В результате снежной бури в США погибли 55 чел...
# 98  В Росавиации опровергли сообщения об обысках у...
# 99  Саакашвили выдвинул условие для проведения у н...
#
#                                    link                   publish_date  \
# 0   https://regnum.ru/news/3765068.html  Tue, 27 Dec 2022 07:26:00 GMT
# 1   https://regnum.ru/news/3765070.html  Tue, 27 Dec 2022 07:27:00 GMT
# 2   https://regnum.ru/news/3765067.html  Tue, 27 Dec 2022 07:25:00 GMT
# 3   https://regnum.ru/news/3765069.html  Tue, 27 Dec 2022 07:26:00 GMT
# 4   https://regnum.ru/news/3765065.html  Tue, 27 Dec 2022 07:15:00 GMT
# ..                                  ...                            ...
# 95  https://regnum.ru/news/3764964.html  Mon, 26 Dec 2022 17:41:00 GMT
# 96  https://regnum.ru/news/3764961.html  Mon, 26 Dec 2022 17:46:00 GMT
# 97  https://regnum.ru/news/3764966.html  Mon, 26 Dec 2022 18:00:00 GMT
# 98  https://regnum.ru/news/3764931.html  Mon, 26 Dec 2022 15:22:00 GMT
# 99  https://regnum.ru/news/3764963.html  Mon, 26 Dec 2022 17:48:00 GMT
#
#         category                                        description  \
# 0       Общество  \nПравоохранительные органы задержали подозрев...
# 1       В России  \nНа территории Хабаровского края медиками зар...
# 2       Политика  \nГлава правительства Каталонии Пере Арагонес ...
# 3   Происшествия  \nВ результате дорожно-транспортного происшест...
# 4       Политика  \nВ вопросе о продолжении предоставления помощ...
# ..           ...                                                ...
# 95     Экономика  \nУкраина поднимет цену на прокачку российской...
# 96      Политика  \nМинистерство иностранных дел Грузии опроверг...
# 97  Происшествия  \nСнежная буря, разыгравшаяся в 12 штатах США,...
# 98      Общество  \nСотрудник управления цифровой трансформации ...
# 99      Политика  \nБывший президент Грузии Михаил Саакашвили со...
#
#            source
# 0   regnum.ru|rss
# 1   regnum.ru|rss
# 2   regnum.ru|rss
# 3   regnum.ru|rss
# 4   regnum.ru|rss
# ..            ...
# 95  regnum.ru|rss
# 96  regnum.ru|rss
# 97  regnum.ru|rss
# 98  regnum.ru|rss
# 99  regnum.ru|rss
#
# [134 rows x 6 columns]

# %% [markdown]
# # Инкрементальная загрузка данных из рсс

# %%
""" Вариант1:
    Скачать порцию данных
    Преобразовать ее в пандас
    Получить самую свежую запись из БД
    Определить в таблице пандас записи более новые, чем самая свежая из БД
    Дописать полученные записи в БД
"""

# %% [markdown]
# # Группировка тематических рубрик

# %% [markdown]
# ## Тематическое моделирование
